# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.txt", sep = '\t')

# %%
df.head(1)
# Out:
#               MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# C.ba.Peri.1  0.050076 -0.131556 -0.065747 -0.064974    -0.060472   -0.089022
#
#              MEdarkorange  MEdarkred  MEdarkturquoise   MEgreen  ...  \
# C.ba.Peri.1     -0.036505  -0.068925        -0.063142 -0.139962  ...
#
#                 MEred  MEroyalblue  MEsaddlebrown  MEsalmon  MEskyblue  \
# C.ba.Peri.1 -0.193872    -0.158176        0.03105 -0.080509  -0.047683
#
#              MEsteelblue     MEtan  MEturquoise   MEwhite  MEyellow
# C.ba.Peri.1    -0.034541 -0.147075     0.162535 -0.075023 -0.047007
#
# [1 rows x 32 columns]

# %%
list(df.index)
# Out:
# ['C.ba.Peri.1',
#  'C.ba.Peri.2',
#  'C.ba.Pla.1',
#  'C.ba.Pla.2',
#  'C.ba.Pla.3',
#  'C.ba.Stem.2',
#  'C.ba.flo.2',
#  'C.ba.ma.peri.1',
#  'C.ba.ma.peri.2',
#  'C.ba.ma.peri.3',
#  'C.ba.ma.pla.1',
#  'C.ba.ma.pla.2',
#  'C.ba.ma.pla.3',
#  'ba.leaf.1',
#  'ba.leaf.2',
#  'ba.leaf.3',
#  'ba.root.1',
#  'ba.root.2',
#  'ba.root.3']

# %%
new_index = [
 'pericarp-1',
 'pericarp-2',
 'placenta-1',
 'placenta-2',
 'placenta-3',
 'stem-2',
 'flower-2',
 'ma.pericarp-1',
 'ma.pericarp-2',
 'ma.pericarp-3',
 'ma.placenta-1',
 'ma.placenta-2',
 'ma.placenta-3',
 'leaf-1',
 'leaf-2',
 'leaf-3',
 'root-1',
 'root-2',
 'root-3']

# %%
df.index = new_index

# %%
df.head(1)
# Out:
#              MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# pericarp-1  0.050076 -0.131556 -0.065747 -0.064974    -0.060472   -0.089022
#
#             MEdarkorange  MEdarkred  MEdarkturquoise   MEgreen  ...     MEred  \
# pericarp-1     -0.036505  -0.068925        -0.063142 -0.139962  ... -0.193872
#
#             MEroyalblue  MEsaddlebrown  MEsalmon  MEskyblue  MEsteelblue  \
# pericarp-1    -0.158176        0.03105 -0.080509  -0.047683    -0.034541
#
#                MEtan  MEturquoise   MEwhite  MEyellow
# pericarp-1 -0.147075     0.162535 -0.075023 -0.047007
#
# [1 rows x 32 columns]

# %%
idx = [
 'root-1',
 'root-2',
 'root-3',
 'stem-2', 
 'leaf-1',
 'leaf-2',
 'leaf-3',
# flower-2         -0.080846  0.621579    -0.450611 -0.063513 -0.101591
# pericarp-1       -0.034541 -0.147075     0.162535 -0.075023 -0.047007
# pericarp-2        0.966973 -0.146386     0.208385 -0.073313 -0.065351
# placenta-1       -0.070323 -0.110211     0.188426 -0.033080 -0.118009
# placenta-2       -0.043721 -0.139531     0.210613  0.970387 -0.119363
# placenta-3       -0.067611 -0.105744     0.206408 -0.050688 -0.107254
# ma.pericarp-1    -0.006639 -0.146127     0.154044 -0.067892 -0.049316
# ma.pericarp-2    -0.054729 -0.150993     0.208721 -0.028635 -0.065967
# ma.pericarp-3     0.031982 -0.123792     0.160224 -0.068777 -0.065125
# ma.placenta-1    -0.058513 -0.119354     0.200284 -0.056638 -0.109762
# ma.placenta-2    -0.075046 -0.127300     0.214656 -0.043146 -0.115849
# ma.placenta-3    -0.073338 -0.097336     0.185361 -0.038588 -0.105114
#
# [19 rows x 32 columns]

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkorange',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MElightcyan',
#  'MElightgreen',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmidnightblue',
#  'MEorange',
#  'MEpaleturquoise',
#  'MEpink',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsaddlebrown',
#  'MEsalmon',
#  'MEskyblue',
#  'MEsteelblue',
#  'MEtan',
#  'MEturquoise',
#  'MEwhite',
#  'MEyellow']

# %%
col = ['MEblack',
 'MEblue',
 'MEbrown',
 'MEcyan',
 'MEdarkgreen',
 'MEdarkgrey',
 'MEdarkorange',
 'MEdarkred',
 'MEdarkturquoise',
 'MEgreen',
 'MEgreenyellow',
 'MEgrey',
 'MEgrey60',
 'MElightcyan',
 'MElightgreen',
 'MElightyellow',
 'MEmagenta',
 'MEmidnightblue',
 'MEorange',
 'MEpaleturquoise',
 'MEpink',
 'MEpurple',
 'MEred',
 'MEroyalblue',
 'MEsaddlebrown',
 'MEsalmon',
 'MEskyblue',
 'MEsteelblue',
 'MEtan',
 'MEturquoise',
 'MEwhite',
 'MEyellow']

# %%
df_reindex = df_reindex[col]

# %%
plt.figure(figsize = (30, 20))
sns.set(font_scale = 2)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
plt.title('Module-sample relationships', fontsize = 30)
# plt.savefig('Module-sample relationships.png')
# plt.savefig('Module-sample relationships.jpg')
# plt.savefig('Module-sample relationships.pdf')
plt.show()
