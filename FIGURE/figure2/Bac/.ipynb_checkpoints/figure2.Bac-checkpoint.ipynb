# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.Chi.txt", sep = '\t')

# %%
df.head(1)
# Out:
#       MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# X22  0.032143  0.499067 -0.089423  0.359136     -0.06649    0.969526
#
#      MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# X22       -0.04905         -0.069107     -0.044651  -0.080653  ...
#
#      MEsaddlebrown  MEsalmon  MEsienna3  MEskyblue  MEsteelblue     MEtan  \
# X22      -0.019225 -0.108256  -0.052474  -0.063505    -0.042052 -0.070596
#
#      MEturquoise  MEviolet   MEwhite  MEyellow
# X22    -0.029436   0.02724 -0.030598 -0.082911
#
# [1 rows x 36 columns]

# %%
list(df.index)
# Out:
# ['X22',
#  'X23',
#  'X24',
#  'X25',
#  'X26',
#  'X27',
#  'C.chi.flo.1',
#  'C.chi.flo.2',
#  'C.chi.flo.3',
#  'C.chi.im.peri.1',
#  'C.chi.im.peri.2',
#  'C.chi.im.peri.3',
#  'C.chi.im.pla.1',
#  'C.chi.im.pla.2',
#  'C.chi.im.pla.3',
#  'Chi.leaf.1',
#  'Chi.leaf.2',
#  'Chi.leaf.3']

# %%
new_index = [
 'stem-1',
 'stem-2',
 'stem-3',
 'root-1',
 'root-2',
 'root-3',
 'flower-1',
 'flower-2',
 'flower-3',
 'pericarp-1',
 'pericarp-2',
 'pericarp-3',
 'placenta-1',
 'placenta-2',
 'placenta-3',
 'leaf-1',
 'leaf-2',
 'leaf-3']

# %%
df.index = new_index

# %%
df.head(1)
# Out:
#          MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# stem-1  0.032143  0.499067 -0.089423  0.359136     -0.06649    0.969526
#
#         MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# stem-1       -0.04905         -0.069107     -0.044651  -0.080653  ...
#
#         MEsaddlebrown  MEsalmon  MEsienna3  MEskyblue  MEsteelblue     MEtan  \
# stem-1      -0.019225 -0.108256  -0.052474  -0.063505    -0.042052 -0.070596
#
#         MEturquoise  MEviolet   MEwhite  MEyellow
# stem-1    -0.029436   0.02724 -0.030598 -0.082911
#
# [1 rows x 36 columns]

# %%
idx = [
 'root-1',
 'root-2',
 'root-3',    
 'stem-1',
 'stem-2',
 'stem-3',
 'leaf-1',
 'leaf-2',
 'leaf-3',
 'flower-1',
 'flower-2',
 'flower-3',
 'placenta-1',
 'placenta-2',
 'placenta-3',    
 'pericarp-1',
 'pericarp-2',
 'pericarp-3'
]

# %%
df_reindex = df.reindex(idx)

# %%
df_reindex
# Out:
#              MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# root-1      0.196574  0.092263 -0.092770 -0.143776    -0.064367   -0.065910
# root-2      0.192633  0.094115 -0.091291 -0.161226    -0.078015   -0.059232
# root-3      0.215469  0.096210 -0.096610 -0.150085    -0.090158   -0.065478
# stem-1      0.032143  0.499067 -0.089423  0.359136    -0.066490    0.969526
# stem-2     -0.008963  0.443447 -0.087748  0.349514    -0.080001   -0.049519
# stem-3      0.085175  0.502583 -0.104468  0.360438    -0.081987   -0.022180
# leaf-1     -0.313282 -0.114730 -0.098018 -0.031818    -0.116386   -0.029560
# leaf-2     -0.393579 -0.136858 -0.088005 -0.027183    -0.115827   -0.045239
# pericarp-3      -0.060114  0.610134  -0.029409  -0.067841    -0.037043
#
#                MEtan  MEturquoise  MEviolet   MEwhite  MEyellow
# root-1      0.297609     0.524085 -0.063906 -0.052932 -0.163392
# root-2      0.267426     0.519031 -0.049828  0.970282 -0.167963
# root-3      0.266440     0.518029 -0.089420 -0.064811 -0.169911
# stem-1     -0.070596    -0.029436  0.027240 -0.030598 -0.082911
# stem-2     -0.109934    -0.045975  0.965674 -0.060089 -0.088615
# stem-3     -0.086238    -0.026209 -0.054105 -0.065830 -0.074467
# leaf-1      0.430415    -0.095943 -0.024257 -0.074067  0.499715
# leaf-2      0.287797    -0.126887 -0.039186 -0.052872  0.511699
# leaf-3      0.377266    -0.092587 -0.037404 -0.036590  0.537773
# flower-1   -0.108050    -0.108958 -0.073577 -0.039267 -0.086758
# flower-2   -0.112045    -0.121752 -0.057575 -0.037365 -0.086328
# flower-3   -0.101057    -0.106048 -0.084871 -0.060450 -0.091502
# placenta-1 -0.206285    -0.118604 -0.081606 -0.070826 -0.147292
# placenta-2 -0.224918    -0.108143 -0.071101 -0.047867 -0.152137
# placenta-3 -0.210552    -0.110565 -0.053247 -0.067149 -0.147998
# pericarp-1 -0.232605    -0.139798 -0.065286 -0.069115 -0.068336
# pericarp-2 -0.235685    -0.160560 -0.067065 -0.070650 -0.020795
# pericarp-3 -0.228986    -0.169681 -0.080480 -0.069803 -0.000783
#
# [18 rows x 36 columns]

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkmagenta',
#  'MEdarkolivegreen',
#  'MEdarkorange',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MElightcyan',
#  'MElightgreen',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmidnightblue',
#  'MEorange',
#  'MEpaleturquoise',
#  'MEpink',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsaddlebrown',
#  'MEsalmon',
#  'MEsienna3',
#  'MEskyblue',
#  'MEsteelblue',
#  'MEtan',
#  'MEturquoise',
#  'MEviolet',
#  'MEwhite',
#  'MEyellow']

# %%
col = [
 'MEgrey',   
 'MEturquoise',    
 'MEblue',    
 'MEyellow',   
 'MEbrown',    
 'MEpurple',    
 'MEsalmon', 
 'MEgreenyellow',
 'MEpink',   
 'MEblack',       
 'MEtan',        
 'MElightgreen',   
 'MEred',     
 'MEcyan',
 'MEdarkturquoise',
 'MEmagenta',
 'MEmidnightblue',
 'MEgreen',    
 'MEgrey60',    
 'MEwhite',    
 'MEdarkorange',    
 'MEdarkgrey',    
 'MEviolet',    
 'MElightcyan',    
 'MEsaddlebrown',    
 'MEskyblue',
 'MEsteelblue',    
 'MEorange',    
 'MEroyalblue',    
 'MElightyellow',    
 'MEdarkmagenta',
 'MEdarkolivegreen',
 'MEdarkgreen',
 'MEdarkred',
 'MEsienna3',
 'MEpaleturquoise'
]

# %%
df_reindex = df_reindex[col]

# %%
plt.figure(figsize = (30, 20))
sns.set(font_scale = 2)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
plt.title('Module-sample relationships', fontsize = 30)
# plt.savefig('Module-sample relationships.png')
# plt.savefig('Module-sample relationships.jpg')
# plt.savefig('Module-sample relationships.pdf')
plt.show()
