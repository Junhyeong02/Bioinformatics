# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.txt", sep = '\t')

# %%
df.head(1)
# Out:
#       MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# X22 -0.064726  0.491939  0.196294 -0.069154    -0.027133   -0.048691
#
#      MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# X22      -0.061712         -0.053637     -0.052755  -0.028256  ...
#
#      MEroyalblue  MEsaddlebrown  MEsalmon  MEskyblue  MEsteelblue     MEtan  \
# X22    -0.025671      -0.034465 -0.174516  -0.027902    -0.039693 -0.055723
#
#      MEturquoise  MEviolet  MEwhite  MEyellow
# X22     0.034821 -0.046094 -0.01305 -0.058929
#
# [1 rows x 35 columns]

# %%
list(df.index)
# Out:
# ['X22',
#  'X23',
#  'X24',
#  'X25',
#  'X26',
#  'X27',
#  'C.Chi.m.peri.1..1',
#  'C.Chi.m.peri.2..2',
#  'C.Chi.m.peri.3..3',
#  'C.chi.flo.1',
#  'C.chi.flo.2',
#  'C.chi.flo.3',
#  'C.chi.im.peri.2',
#  'C.chi.im.peri.3',
#  'C.chi.im.pla.1',
#  'C.chi.im.pla.2',
#  'C.chi.im.pla.3',
#  'C.Chi.mpla.1',
#  'C.Chi.mpla.2',
#  'C.Chi.mpla.3',
#  'Chi.leaf.1',
#  'Chi.leaf.2',
#  'Chi.leaf.3']

# %%
new_index = [
 'stem-1',
 'stem-2',
 'stem-3',
 'root-1',
 'root-2',
 'root-3',
 'ma.pericarp-1',
 'ma.pericarp-2',
 'ma.pericarp-3',
 'flower-1',
 'flower-2',
 'flower-3',
 'im.pericarp-2',
 'im.pericarp-3',
 'im.placenta-1',
 'im.placenta-2',
 'im.placenta-3',
 'ma.placenta-1',
 'ma.placenta-2',
 'ma.placenta-3',
 'leaf-1',
 'leaf-2',
 'leaf-3']

# %%
df.index = new_index

# %%
df.head(1)
# Out:
#          MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# stem-1 -0.064726  0.491939  0.196294 -0.069154    -0.027133   -0.048691
#
#         MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# stem-1      -0.061712         -0.053637     -0.052755  -0.028256  ...
#
#         MEroyalblue  MEsaddlebrown  MEsalmon  MEskyblue  MEsteelblue  \
# stem-1    -0.025671      -0.034465 -0.174516  -0.027902    -0.039693
#
#            MEtan  MEturquoise  MEviolet  MEwhite  MEyellow
# stem-1 -0.055723     0.034821 -0.046094 -0.01305 -0.058929
#
# [1 rows x 35 columns]

# %%
idx = [
 'root-1',
 'root-2',
 'root-3',    
 'stem-1',
 'stem-2',
 'stem-3',
 'leaf-1',
 'leaf-2',
 'leaf-3',
 'flower-1',
 'flower-2',
 'flower-3',
 'im.pericarp-2',
 'im.pericarp-3',
 'im.placenta-1',
 'im.placenta-2',
 'im.placenta-3',    
 'ma.pericarp-1',
 'ma.pericarp-2',
 'ma.pericarp-3',
 'ma.placenta-1',
 'ma.placenta-2',
 'ma.placenta-3'
]

# %%
df_reindex = df.reindex(idx)

# %%
df_reindex
# Out:
#                 MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  \
# root-1        -0.090114  0.109877  0.174995 -0.136809    -0.057352
# root-2        -0.086635  0.108513  0.191993 -0.129283    -0.047301
# root-3        -0.082408  0.112248  0.198573 -0.130278    -0.043237
# stem-1        -0.064726  0.491939  0.196294 -0.069154    -0.027133
# stem-2        -0.071728  0.441065  0.156891 -0.045037    -0.039568
# stem-3        -0.044883  0.492508  0.232219 -0.083037    -0.050455
# leaf-1        -0.105764 -0.021878  0.017808  0.358554    -0.037293
# leaf-2        -0.124718 -0.041446 -0.013510  0.424941    -0.043142
# leaf-3        -0.088679 -0.011323  0.060152  0.350005     0.977163
# flower-1      -0.046065  0.010334  0.004311  0.300965    -0.034186
# flower-2      -0.062221 -0.001393 -0.020239  0.345901    -0.049815
# flower-3      -0.039412  0.011836  0.019416  0.288880    -0.049942
# im.pericarp-2  0.247701 -0.134701  0.092245 -0.096046    -0.042525
# ...

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkmagenta',
#  'MEdarkolivegreen',
#  'MEdarkorange',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MElightcyan',
#  'MElightgreen',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmidnightblue',
#  'MEorange',
#  'MEpaleturquoise',
#  'MEpink',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsaddlebrown',
#  'MEsalmon',
#  'MEskyblue',
#  'MEsteelblue',
#  'MEtan',
#  'MEturquoise',
#  'MEviolet',
#  'MEwhite',
#  'MEyellow']

# %%
col = ['MEblack',
 'MEblue',
 'MEbrown',
 'MEcyan',
 'MEdarkgreen',
 'MEdarkgrey',
 'MEdarkmagenta',
 'MEdarkolivegreen',
 'MEdarkorange',
 'MEdarkred',
 'MEdarkturquoise',
 'MEgreen',
 'MEgreenyellow',
 'MEgrey',
 'MEgrey60',
 'MElightcyan',
 'MElightgreen',
 'MElightyellow',
 'MEmagenta',
 'MEmidnightblue',
 'MEorange',
 'MEpaleturquoise',
 'MEpink',
 'MEpurple',
 'MEred',
 'MEroyalblue',
 'MEsaddlebrown',
 'MEsalmon',
 'MEskyblue',
 'MEsteelblue',
 'MEtan',
 'MEturquoise',
 'MEviolet',
 'MEwhite',
 'MEyellow']

# %%
df_reindex = df_reindex[col]

# %%
plt.figure(figsize = (30, 20))
sns.set(font_scale = 2)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
plt.title('Module-sample relationships', fontsize = 30)
# plt.savefig('Module-sample relationships.png')
# plt.savefig('Module-sample relationships.jpg')
# plt.savefig('Module-sample relationships.pdf')
plt.show()
