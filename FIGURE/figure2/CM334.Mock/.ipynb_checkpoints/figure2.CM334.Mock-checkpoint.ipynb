# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.CM334.Mock.txt", sep = '\t')

# %%
df.head(1)
# Out:
#                 MEblack   MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# CM.Mock.V.0.1 -0.127995  0.02474 -0.140943 -0.078044     0.030952    -0.06888
#
#                MEdarkred  MEdarkturquoise   MEgreen  MEgreenyellow  ...  \
# CM.Mock.V.0.1   0.961608        -0.051635 -0.004964      -0.076989  ...
#
#                MEmagenta  MEmidnightblue    MEpink  MEpurple     MEred  \
# CM.Mock.V.0.1   -0.11044       -0.076576  0.030257 -0.134541 -0.166793
#
#                MEroyalblue  MEsalmon     MEtan  MEturquoise  MEyellow
# CM.Mock.V.0.1    -0.083285 -0.040946 -0.086508    -0.168639 -0.076773
#
# [1 rows x 25 columns]

# %%
list(df.index)
# Out:
# ['CM.Mock.V.0.1',
#  'CM.Mock.V.0.2',
#  'CM.Mock.V.0.3',
#  'CM.Mock.V.1D.1',
#  'CM.Mock.V.1D.2',
#  'CM.Mock.V.1D.3',
#  'CM.Mock.V.2D.1',
#  'CM.Mock.V.2D.2',
#  'CM.Mock.V.2D.3',
#  'CM.Mock.V.30m.1',
#  'CM.Mock.V.30m.2',
#  'CM.Mock.V.3D.2',
#  'CM.Mock.V.3D.3',
#  'CM.Mock.V.4h.1',
#  'CM.Mock.V.4h.2',
#  'CM.Mock.V.4h.3',
#  'CM.Mock.V.up.1',
#  'CM.Mock.V.up.2']

# %%
new_index = [
 'Mock.0-1',
 'Mock.0-2',
 'Mock.0-3',
 'Mock.1D-1',
 'Mock.1D-2',
 'Mock.1D-3',
 'Mock.2D-1',
 'Mock.2D-2',
 'Mock.2D-3',
 'Mock.30m-1',
 'Mock.30m-2',
 'Mock.3D-2',
 'Mock.3D-3',
 'Mock.4h-1',
 'Mock.4h-2',
 'Mock.4h-3',
 'Mock.up-1',
 'Mock.up-2'
]

# %%
df.index = new_index

# %%
df.tail(1)
# Out:
#             MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# Mock.up-2  0.006899 -0.319376  0.679899 -0.019272     0.388464   -0.077947
#
#            MEdarkred  MEdarkturquoise   MEgreen  MEgreenyellow  ...  \
# Mock.up-2  -0.119716        -0.106549  0.007393      -0.087186  ...
#
#            MEmagenta  MEmidnightblue    MEpink  MEpurple     MEred  \
# Mock.up-2   0.018036       -0.022614 -0.027174 -0.246601 -0.205129
#
#            MEroyalblue  MEsalmon     MEtan  MEturquoise  MEyellow
# Mock.up-2    -0.075367 -0.062337 -0.065138     0.191903 -0.086661
#
# [1 rows x 25 columns]

# %%
idx = [
 'Mock.0-1',
 'Mock.0-2',
 'Mock.0-3',
 'Mock.30m-1',
 'Mock.30m-2',  
 'Mock.4h-1',
 'Mock.4h-2',
 'Mock.4h-3',    
 'Mock.1D-1',
 'Mock.1D-2',
 'Mock.1D-3',
 'Mock.2D-1',
 'Mock.2D-2',
 'Mock.2D-3',
 'Mock.3D-2',
 'Mock.3D-3',
 'Mock.up-1',
 'Mock.up-2'
]

# %%
df_reindex = df.reindex(idx)

# %%
df_reindex
# Out:
#              MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# Mock.0-1   -0.127995  0.024740 -0.140943 -0.078044     0.030952   -0.068880
# Mock.0-2   -0.108331  0.165371 -0.199440 -0.085476    -0.217001   -0.125963
# Mock.0-3   -0.048052  0.240796 -0.165661 -0.066715     0.248769   -0.109508
# Mock.30m-1 -0.058247  0.199770 -0.151639 -0.075709    -0.255360   -0.110241
# Mock.30m-2 -0.064025  0.158602 -0.137780 -0.051015     0.405441   -0.108239
# Mock.4h-1  -0.020718  0.301419  0.069512 -0.039850    -0.231126   -0.088531
# Mock.4h-2   0.156856  0.227622  0.104137  0.969145     0.525829   -0.025711
# Mock.4h-3   0.934770  0.392223  0.080479 -0.025300    -0.103220   -0.052927
# Mock.1D-1  -0.117903  0.035696 -0.140853 -0.072619    -0.255996   -0.075995
# Mock.1D-2  -0.106726  0.074358 -0.168399 -0.066947    -0.134851   -0.090062
# Mock.1D-3  -0.009894  0.092637 -0.115792 -0.061987    -0.221057   -0.109016
# Mock.2D-1  -0.107400 -0.275058 -0.063328 -0.070219    -0.080753   -0.016598
# Mock.2D-2  -0.085261 -0.250201 -0.051656 -0.056371    -0.005292   -0.044241
# Mock.2D-3  -0.019716 -0.176177 -0.020996 -0.040294    -0.102183    0.674314
# Mock.3D-2  -0.104705 -0.290090 -0.090039 -0.056804     0.077493   -0.100225
# Mock.3D-3  -0.075779 -0.312455 -0.042383 -0.060329    -0.109094    0.647688
# Mock.up-1  -0.043774 -0.289877  0.554882 -0.042196     0.038985   -0.117918
# Mock.up-2   0.006899 -0.319376  0.679899 -0.019272     0.388464   -0.077947
#
#             MEdarkred  MEdarkturquoise   MEgreen  MEgreenyellow  ...  \
# Mock.0-1     0.961608        -0.051635 -0.004964      -0.076989  ...
# Mock.0-2    -0.048730        -0.080075 -0.166519      -0.074311  ...
# Mock.0-3    -0.014697        -0.079588 -0.087738      -0.052191  ...
# Mock.30m-1  -0.079755        -0.051332 -0.255979      -0.126474  ...
# Mock.30m-2  -0.050018        -0.055400 -0.119158      -0.080957  ...
# Mock.4h-1   -0.073824        -0.099866  0.861597      -0.041121  ...
# Mock.4h-2   -0.018169         0.008418  0.146559       0.001144  ...
# Mock.4h-3   -0.055461        -0.065512 -0.088827      -0.071490  ...
# Mock.1D-1   -0.093424        -0.049960  0.115180       0.962072  ...
# Mock.1D-2   -0.060566         0.965521 -0.225073      -0.071663  ...
# Mock.1D-3   -0.039354        -0.014132 -0.171154      -0.042169  ...
# Mock.2D-1   -0.036209        -0.050037  0.104299      -0.022580  ...
# Mock.2D-2   -0.059055        -0.065416  0.020823      -0.002710  ...
# Mock.2D-3   -0.051296        -0.055967  0.011115      -0.041017  ...
# Mock.3D-2   -0.067842        -0.030036 -0.030300      -0.043369  ...
# Mock.3D-3    0.025088        -0.044431 -0.076033      -0.019897  ...
# Mock.up-1   -0.118581        -0.074003 -0.041221      -0.109089  ...
# Mock.up-2   -0.119716        -0.106549  0.007393      -0.087186  ...
#
#             MEmagenta  MEmidnightblue    MEpink  MEpurple     MEred  \
# Mock.0-1    -0.110440       -0.076576  0.030257 -0.134541 -0.166793
# Mock.0-2    -0.122816       -0.070978 -0.182382 -0.179149 -0.193386
# Mock.0-3    -0.072702       -0.016777 -0.144654 -0.234006 -0.126465
# Mock.30m-1  -0.173289       -0.073372 -0.361524 -0.300015 -0.152013
# Mock.30m-2  -0.098459        0.966141 -0.172254 -0.082592 -0.120846
# Mock.4h-1   -0.047490       -0.040889  0.129027  0.100443 -0.093695
# Mock.4h-2   -0.004138        0.015073 -0.077936  0.108237 -0.135614
# Mock.4h-3    0.009102       -0.057944 -0.185101  0.243103 -0.160122
# Mock.1D-1   -0.050913       -0.070962  0.180631  0.404495  0.135677
# Mock.1D-2   -0.124584       -0.086375 -0.172967  0.381764 -0.137440
# Mock.1D-3   -0.051488       -0.070319 -0.093735  0.407365 -0.053312
# Mock.2D-1    0.035317       -0.077855  0.774796  0.080499  0.138285
# Mock.2D-2    0.036921       -0.083969  0.116234  0.036911  0.200201
# Mock.2D-3    0.942887       -0.058291  0.158826  0.108380  0.249568
# Mock.3D-2   -0.040757       -0.059312  0.055773 -0.215410  0.516242
# Mock.3D-3   -0.058145       -0.048599  0.066493 -0.255853  0.547131
# Mock.up-1   -0.087041       -0.066382 -0.094311 -0.223032 -0.242291
# Mock.up-2    0.018036       -0.022614 -0.027174 -0.246601 -0.205129
#
#             MEroyalblue  MEsalmon     MEtan  MEturquoise  MEyellow
# Mock.0-1      -0.083285 -0.040946 -0.086508    -0.168639 -0.076773
# Mock.0-2      -0.064782 -0.084842 -0.103205    -0.220600 -0.030539
# Mock.0-3      -0.064116 -0.084206 -0.056396    -0.142566 -0.012609
# Mock.30m-1    -0.061636 -0.090318 -0.075574    -0.140241  0.679385
# Mock.30m-2    -0.068401 -0.055929 -0.068459    -0.119881  0.622670
# Mock.4h-1     -0.048304 -0.081394 -0.057512     0.543936 -0.018637
# Mock.4h-2     -0.038915 -0.041792 -0.015404     0.365376 -0.018571
# Mock.4h-3     -0.073434 -0.034297 -0.061693     0.493382 -0.028580
# Mock.1D-1     -0.064791 -0.048085 -0.034565    -0.098096 -0.145993
# Mock.1D-2     -0.103636 -0.007981 -0.105218    -0.211227 -0.132453
# Mock.1D-3     -0.042666  0.968128 -0.051303    -0.105283 -0.118405
# Mock.2D-1     -0.022889 -0.041362 -0.042836    -0.100336 -0.169353
# Mock.2D-2     -0.014064 -0.053781 -0.023085    -0.091967 -0.141030
# Mock.2D-3     -0.054662 -0.039936 -0.021137    -0.050855 -0.143445
# Mock.3D-2     -0.010254 -0.064134  0.965212    -0.158368 -0.041569
# Mock.3D-3      0.966976 -0.067377 -0.012366    -0.147068 -0.041171
# Mock.up-1     -0.075774 -0.069412 -0.084814     0.160529 -0.096265
# Mock.up-2     -0.075367 -0.062337 -0.065138     0.191903 -0.086661
#
# [18 rows x 25 columns]

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MElightcyan',
#  'MElightgreen',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmidnightblue',
#  'MEpink',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsalmon',
#  'MEtan',
#  'MEturquoise',
#  'MEyellow']

# %%
col = [
 'MEgrey',    
 'MEyellow',   
 'MEblue',    
 'MEturquoise',
 'MEpurple',    
 'MEred',    
 'MEbrown',    
    

 'MEdarkgreen',
 'MEdarkgrey',


      
 'MEdarkred',      
 'MElightyellow',      
 'MEgrey60',
 'MElightcyan', 
 'MEmidnightblue', 
 'MEgreen',    
 'MEcyan',    
 'MEblack',    
 'MEgreenyellow',  
 'MEdarkturquoise',    
 'MEsalmon',    
 'MEpink',    
 'MElightgreen',    
 'MEmagenta',    
 'MEtan',  
 'MEroyalblue'
]

# %%
df_reindex = df_reindex[col]

# %%
plt.figure(figsize = (30, 20))
sns.set(font_scale = 2)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
plt.title('Module-sample relationships', fontsize = 30)
plt.savefig('Module-sample relationships.CM334.Mock.png')
# plt.savefig('Module-sample relationships.jpg')
# plt.savefig('Module-sample relationships.pdf')
plt.show()
