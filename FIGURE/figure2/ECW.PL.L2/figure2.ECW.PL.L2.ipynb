# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.txt", sep = '\t')

# %%
df.head(1)
# Out:
#          MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# ECW1.1 -0.152874  0.317569 -0.163929 -0.034273    -0.060712    -0.07294
#
#         MEdarkolivegreen  MEdarkorange  MEdarkred  MEdarkturquoise  ...  \
# ECW1.1         -0.060715     -0.089917  -0.049045         -0.07983  ...
#
#         MEroyalblue  MEsaddlebrown  MEsalmon  MEskyblue  MEsteelblue  \
# ECW1.1     -0.05986      -0.071876 -0.016103  -0.072711       -0.072
#
#            MEtan  MEturquoise  MEviolet   MEwhite  MEyellow
# ECW1.1 -0.082381     0.546802 -0.048447 -0.059004  -0.13233
#
# [1 rows x 34 columns]

# %%
list(df.index)
# Out:
# ['ECW1.1',
#  'ECW1.2',
#  'ECW1.3',
#  'ECW2.1',
#  'ECW2.2',
#  'ECW2.3',
#  'ECW3.1A',
#  'ECW3.2A',
#  'ECW3.3A',
#  'ECWB.1',
#  'ECWB.2',
#  'ECWB.3',
#  'ECWB10.1',
#  'ECWB10.2',
#  'ECWB10.3',
#  'ECWB5.1',
#  'ECWB5.2',
#  'ECWB5.3',
#  'ECWMG.1',
#  'ECWMG.2',
#  'ECWMG.3']

# %%
new_index = ['E1.1',
 'E1.2',
 'E1.3',
 'E2.1',
 'E2.2',
 'E2.3',
 'E3.1A',
 'E3.2A',
 'E3.3A',
 'B.1',
 'B.2',
 'B.3',
 'B10.1',
 'B10.2',
 'B10.3',
 'B5.1',
 'B5.2',
 'B5.3',
 'MG.1',
 'MG.2',
 'MG.3']

# %%
df.index = new_index

# %%
df.tail(2)
# Out:
#        MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# MG.2 -0.091718 -0.077967 -0.109697 -0.058063    -0.040804   -0.034455
# MG.3 -0.103298 -0.093437 -0.123072 -0.060440    -0.057805   -0.049854
#
#       MEdarkolivegreen  MEdarkorange  MEdarkred  MEdarkturquoise  ...  \
# MG.2         -0.036154     -0.055993  -0.037888        -0.022582  ...
# MG.3         -0.017698     -0.033938  -0.061254         0.007321  ...
#
#       MEroyalblue  MEsaddlebrown  MEsalmon  MEskyblue  MEsteelblue     MEtan  \
# MG.2    -0.040436      -0.015596 -0.046407  -0.037704    -0.047448 -0.049510
# MG.3    -0.062602      -0.049642 -0.060949  -0.037854    -0.062730 -0.025417
#
#       MEturquoise  MEviolet   MEwhite  MEyellow
# MG.2    -0.083407  -0.05499 -0.019174 -0.119786
# MG.3    -0.095773  -0.05657  0.971607 -0.137111
#
# [2 rows x 34 columns]

# %%
idx = [
 'E1.1',
 'E1.2',
 'E1.3',
 'E2.1',
 'E2.2',
 'E2.3',
 'E3.1A',
 'E3.2A',
 'E3.3A',
 'MG.1',
 'MG.2',
 'MG.3',    
 'B.1',
 'B.2',
 'B.3',
 'B5.1',
 'B5.2',
 'B5.3',    
 'B10.1',
 'B10.2',
 'B10.3'
]

# %%
df_reindex = df.reindex(idx)

# %%
df_reindex
# Out:
#         MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# E1.1  -0.152874  0.317569 -0.163929 -0.034273    -0.060712   -0.072940
# E1.2  -0.117637  0.351307 -0.125726  0.974081    -0.048727   -0.072312
# E1.3  -0.130148  0.332175 -0.153172 -0.007513    -0.030611   -0.070725
# E2.1   0.536939  0.259343 -0.148421 -0.039195    -0.061136   -0.043176
# E2.2   0.481920  0.263979 -0.154339 -0.039819    -0.053183   -0.028824
# E2.3   0.504830  0.259650 -0.151485 -0.034463    -0.067118   -0.039551
# E3.1A  0.046182  0.110312 -0.085959 -0.042927    -0.019165   -0.049504
# E3.2A  0.075615  0.102362 -0.102513 -0.051567     0.973951   -0.048713
# E3.3A  0.055306  0.110441 -0.092497 -0.045302    -0.017529   -0.049055
# MG.1  -0.091042 -0.105128 -0.126721 -0.052699    -0.035291   -0.023146
# MG.2  -0.091718 -0.077967 -0.109697 -0.058063    -0.040804   -0.034455
# MG.3  -0.103298 -0.093437 -0.123072 -0.060440    -0.057805   -0.049854
# B.1   -0.015936 -0.096104 -0.137127 -0.047028    -0.055831    0.972046
# B.2   -0.073699 -0.124991 -0.146565 -0.061363    -0.051749    0.004401
# B.3   -0.126138 -0.165919 -0.047196 -0.042418    -0.075019   -0.030506
# B5.1  -0.105004 -0.236003  0.127315 -0.062762    -0.048666   -0.050235
# B5.2  -0.104136 -0.230363  0.156556 -0.050837    -0.052147   -0.042679
# B5.3  -0.109635 -0.228234  0.146123 -0.071227    -0.046701   -0.056325
# B10.1 -0.156458 -0.245236  0.487441 -0.060191    -0.054893   -0.077233
# B10.2 -0.164363 -0.246542  0.497901 -0.054926    -0.052171   -0.064718
# B10.3 -0.158708 -0.257216  0.453082 -0.057069    -0.044692   -0.072498
#
#        MEdarkolivegreen  MEdarkorange  MEdarkred  MEdarkturquoise  ...  \
# E1.1          -0.060715     -0.089917  -0.049045        -0.079830  ...
# E1.2          -0.049959     -0.082849  -0.053163        -0.080224  ...
# E1.3          -0.056498     -0.053277  -0.048719        -0.068843  ...
# E2.1          -0.055563     -0.063273  -0.031367        -0.066839  ...
# E2.2          -0.046335      0.023953  -0.030155        -0.026492  ...
# E2.3          -0.060127      0.000809  -0.042360        -0.048083  ...
# E3.1A         -0.039624     -0.067731   0.973020        -0.032479  ...
# E3.2A         -0.058329     -0.078714  -0.062003        -0.075783  ...
# E3.3A         -0.042699     -0.088388   0.002234        -0.071504  ...
# MG.1           0.974587     -0.095053  -0.034454        -0.038335  ...
# MG.2          -0.036154     -0.055993  -0.037888        -0.022582  ...
# E3.1A    -0.040145 -0.048012 -0.009346  0.388558
# E3.2A    -0.052779 -0.056873 -0.068523  0.402974
# E3.3A    -0.048249 -0.050452 -0.037474  0.399044
# MG.1     -0.102206 -0.072548 -0.021765 -0.183042
# MG.2     -0.083407 -0.054990 -0.019174 -0.119786
# MG.3     -0.095773 -0.056570  0.971607 -0.137111
# B.1      -0.128513 -0.065875 -0.025118 -0.134496
# B.2      -0.103238 -0.043188 -0.009748 -0.259841
# B.3      -0.098038 -0.037241 -0.054362 -0.241738
# B5.1     -0.144297 -0.034545 -0.063371 -0.093112
# B5.2     -0.135185 -0.050309 -0.069435 -0.070384
# B5.3     -0.129200 -0.025827 -0.057777 -0.122037
# B10.1    -0.105783 -0.040569 -0.069698 -0.117726
# B10.2    -0.093885 -0.054651 -0.046084 -0.137471
# B10.3    -0.108306  0.974860 -0.083879 -0.122856
#
# [21 rows x 34 columns]

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkolivegreen',
#  'MEdarkorange',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MElightcyan',
#  'MElightgreen',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmidnightblue',
#  'MEorange',
#  'MEpaleturquoise',
#  'MEpink',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsaddlebrown',
#  'MEsalmon',
#  'MEskyblue',
#  'MEsteelblue',
#  'MEtan',
#  'MEturquoise',
#  'MEviolet',
#  'MEwhite',
#  'MEyellow']

# %%
col = [
 'MEgrey',    
 'MEturquoise',    
 'MEblack',  
 'MEyellow',    
 'MEpurple',    
 'MEpink',
 'MEgreen',   
 'MEbrown',  
 'MEblue',
 'MEgreenyellow',
 'MEgrey60',
 'MEmagenta',
 'MEred',
 'MElightyellow',       
 'MEcyan',       
 'MEsalmon',       
 'MElightcyan',       
 'MEtan',       
 'MEroyalblue',       
 'MEdarkred',       
 'MEdarkgreen',       
 'MEorange',       
 'MEdarkolivegreen',       
 'MElightgreen',       
 'MEwhite',       
 'MEdarkgrey',       
 'MEpaleturquoise',       
 'MEdarkturquoise',       
 'MEsteelblue',       
 'MEdarkorange',       
 'MEmidnightblue',       
 'MEskyblue',      
 'MEsaddlebrown',      
 'MEviolet'  
]

# %%
df_reindex = df_reindex[col]

# %%
plt.figure(figsize = (30, 20))
sns.set(font_scale = 2)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
# plt.title('Module-sample relationships', fontsize = 30)
plt.savefig('Module-sample relationships.ECW.PL.L2.png')
# plt.savefig('Module-sample relationships.jpg')
# plt.savefig('Module-sample relationships.pdf')
plt.show()
