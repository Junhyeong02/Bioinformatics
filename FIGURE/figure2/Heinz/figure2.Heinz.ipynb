# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.Heinz.txt", sep = '\t')

# %%
df.head(1)
# Out:
#             MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# SRR404309  0.659176 -0.201952 -0.386403 -0.270183    -0.076069   -0.062911
#
#            MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# SRR404309      -0.048657         -0.066421     -0.053773  -0.082151  ...
#
#            MEsienna3  MEskyblue  MEskyblue3  MEsteelblue     MEtan  \
# SRR404309   0.972871  -0.071713   -0.047398    -0.056205 -0.097411
#
#            MEturquoise  MEviolet   MEwhite  MEyellow  MEyellowgreen
# SRR404309    -0.075398 -0.061247 -0.036404 -0.092588      -0.044514
#
# [1 rows x 39 columns]

# %%
list(df.index)
# Out:
# ['SRR404309',
#  'SRR404310',
#  'SRR404311',
#  'SRR404312',
#  'SRR404313',
#  'SRR404314',
#  'SRR404315',
#  'SRR404316',
#  'SRR404317',
#  'SRR404318',
#  'SRR404319',
#  'SRR404320',
#  'SRR404321',
#  'SRR404322',
#  'SRR404324',
#  'SRR404325',
#  'SRR404326',
#  'SRR404327',
#  'SRR404328',
#  'SRR404329']

# %%
new_index = [
 'leaf-1',
 'leaf-2',
 'root-1',
 'root-2',
 'flower-1',
 'flower-2',
 'bud-1',
 'bud-2',
 'fruit1-1',
 'fruit1-2',
 'fruit2-1',
 'fruit2-2',
 'fruit3-1',
 'fruit3-2',
 'fruitMG-1',
 'fruitMG-2',
 'fruitB-1',
 'fruitB-2',
 'fruitB10-1',
 'fruitB10-2']

# %%
df.index = new_index

# %%
df.head(1)
# Out:
#          MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# leaf-1  0.659176 -0.201952 -0.386403 -0.270183    -0.076069   -0.062911
#
#         MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# leaf-1      -0.048657         -0.066421     -0.053773  -0.082151  ...
#
#         MEsienna3  MEskyblue  MEskyblue3  MEsteelblue     MEtan  MEturquoise  \
# leaf-1   0.972871  -0.071713   -0.047398    -0.056205 -0.097411    -0.075398
#
#         MEviolet   MEwhite  MEyellow  MEyellowgreen
# leaf-1 -0.061247 -0.036404 -0.092588      -0.044514
#
# [1 rows x 39 columns]

# %%
idx = [
 'root-1',
 'root-2',    
 'leaf-1',
 'leaf-2',
 'bud-1',
 'bud-2',    
 'flower-1',
 'flower-2',
 'fruit1-1',
 'fruit1-2',
 'fruit2-1',
 'fruit2-2',
 'fruit3-1',
 'fruit3-2',
 'fruitMG-1',
 'fruitMG-2',
 'fruitB-1',
 'fruitB-2',
 'fruitB10-1',
 'fruitB10-2']

# %%
df_reindex = df.reindex(idx)

# %%
df_reindex
# Out:
# fruit3-1      -0.076105 -0.019289 -0.060448 -0.102648      -0.018604
# fruit3-2      -0.076272 -0.014675 -0.054196 -0.101961       0.018100
# fruitMG-1     -0.056986 -0.044510 -0.061398 -0.104884       0.969306
# fruitMG-2     -0.057184 -0.067051 -0.059446 -0.104381      -0.040413
# fruitB-1      -0.103668 -0.070380 -0.060193 -0.118789      -0.062618
# fruitB-2      -0.104192 -0.083636 -0.058135 -0.117823      -0.066146
# fruitB10-1    -0.106238 -0.033154 -0.033687 -0.116469      -0.055481
# fruitB10-2    -0.106246 -0.062907 -0.038915 -0.118457      -0.071425
#
# [20 rows x 39 columns]

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkmagenta',
#  'MEdarkolivegreen',
#  'MEdarkorange',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MElightcyan',
#  'MElightgreen',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmidnightblue',
#  'MEorange',
#  'MEpaleturquoise',
#  'MEpink',
#  'MEplum1',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsaddlebrown',
#  'MEsalmon',
#  'MEsienna3',
#  'MEskyblue',
#  'MEskyblue3',
#  'MEsteelblue',
#  'MEtan',
#  'MEturquoise',
#  'MEviolet',
#  'MEwhite',
#  'MEyellow',
#  'MEyellowgreen']

# %%
col = [
 'MEgrey',   
 'MEturquoise',
 'MEblack',     
 'MEyellow',    
 'MEpink',   
 'MEblue',     
 'MEmagenta',    
 'MEbrown',    
 'MEmidnightblue',   
 'MEgreenyellow',   
 'MEgreen',  
    
    
 'MEpurple',    
 'MEsalmon', 

  
      
 'MEtan',        
  
 'MEred',     
 'MEcyan',



    
 'MEorange',    
 'MEdarkmagenta',
 'MEdarkred',
    
    
 'MElightyellow',    
 'MElightgreen',     
 'MEsienna3',    
 'MEdarkolivegreen',    
 'MElightcyan',      
 'MEgrey60',    
 'MEwhite',    
 'MEdarkorange',     
 'MEskyblue',    
 'MEdarkturquoise',    
 'MEviolet',        
 'MEroyalblue',    
 'MEdarkgreen',    
 'MEdarkgrey',    
 'MEsaddlebrown',  
 'MEpaleturquoise',    
 'MEsteelblue'   
]

# %%
df_reindex = df_reindex[col]

# %%
plt.figure(figsize = (30, 20))
sns.set(font_scale = 2)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
# plt.title('Module-sample relationships', fontsize = 30)
# plt.savefig('Module-sample relationships.png')
# plt.savefig('Module-sample relationships.jpg')f
# plt.savefig('Module-sample relationships.pdf')
plt.show()
