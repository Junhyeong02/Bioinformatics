# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.CM334.immun.txt", sep = '\t')

# %%
df.head(1)
# Out:
#                            MEblack    MEblue   MEbrown  MEbrown4    MEcyan  \
# CM334.Mock_CM.Mock.V.0.1  0.020694 -0.051823 -0.043303  0.004311 -0.025367
#
#                           MEdarkgreen  MEdarkgrey  MEdarkmagenta  \
# CM334.Mock_CM.Mock.V.0.1     -0.03813   -0.010358      -0.010666
#
#                           MEdarkolivegreen  MEdarkorange  ...  MEsienna3  \
# CM334.Mock_CM.Mock.V.0.1         -0.013568     -0.010313  ...  -0.009348
#
#                           MEskyblue  MEskyblue3  MEsteelblue     MEtan  \
# CM334.Mock_CM.Mock.V.0.1  -0.009556   -0.006561     -0.01205 -0.013461
#
#                           MEturquoise  MEviolet   MEwhite  MEyellow  \
# CM334.Mock_CM.Mock.V.0.1     -0.07648 -0.009893 -0.012231 -0.051104
#
#                           MEyellowgreen
# CM334.Mock_CM.Mock.V.0.1      -0.012645
#
# [1 rows x 47 columns]

# %%
list(df.index)
# Out:
# ['CM334.Mock_CM.Mock.V.0.1',
#  'CM334.Mock_CM.Mock.V.0.2',
#  'CM334.Mock_CM.Mock.V.0.3',
#  'CM334.Mock_CM.Mock.V.1D.1',
#  'CM334.Mock_CM.Mock.V.1D.2',
#  'CM334.Mock_CM.Mock.V.1D.3',
#  'CM334.Mock_CM.Mock.V.2D.1',
#  'CM334.Mock_CM.Mock.V.2D.2',
#  'CM334.Mock_CM.Mock.V.2D.3',
#  'CM334.Mock_CM.Mock.V.30m.1',
#  'CM334.Mock_CM.Mock.V.30m.2',
#  'CM334.Mock_CM.Mock.V.30m.3',
#  'CM334.Mock_CM.Mock.V.3D.1',
#  'CM334.Mock_CM.Mock.V.3D.2',
#  'CM334.Mock_CM.Mock.V.3D.3',
#  'CM334.Mock_CM.Mock.V.4h.1',
#  'CM334.Mock_CM.Mock.V.4h.2',
#  'CM334.Mock_CM.Mock.V.4h.3',
#  'CM334.Mock_CM.Mock.V.up.1',
#  'CM334.Mock_CM.Mock.V.up.2',
#  'CM334.Pc_CM.0h.1',
#  'CM334.Pc_CM.0h.2',
#  'CM334.Pc_CM.0h.3',
#  'CM334.Pc_CM.PC.12h.1',
#  'CM334.Pc_CM.PC.12h.2',
#  'CM334.Pc_CM.PC.12h.3',
#  'CM334.Pc_CM.PC.1D.1',
#  'CM334.Pc_CM.PC.1D.2',
#  'CM334.Pc_CM.PC.1D.3',
#  'CM334.Pc_CM.PC.1h.1',
#  'CM334.Pc_CM.PC.1h.2',
#  'CM334.Pc_CM.PC.1h.3',
#  'CM334.Pc_CM.PC.2h.1',
#  'CM334.Pc_CM.PC.2h.2',
#  'CM334.Pc_CM.PC.2h.3',
#  'CM334.Pc_CM.PC.4h.1',
#  'CM334.Pc_CM.PC.4h.2',
#  'CM334.Pc_CM.PC.4h.3',
#  'CM334.Pc_CM.PC.6h.1',
#  'CM334.Pc_CM.PC.6h.2',
#  'CM334.Pc_CM.PC.6h.3',
#  'CM334.Pc_CM.PC.TDW.12h.1',
#  'CM334.Pc_CM.PC.TDW.12h.2',
#  'CM334.Pc_CM.PC.TDW.12h.3',
#  'CM334.Pc_CM.PC.TDW.1D.1',
#  'CM334.Pc_CM.PC.TDW.1D.2',
#  'CM334.Pc_CM.PC.TDW.1D.3',
#  'CM334.Pc_CM.PC.TDW.1h.1',
#  'CM334.Pc_CM.PC.TDW.1h.2',
#  'CM334.Pc_CM.PC.TDW.1h.3',
#  'CM334.Pc_CM.PC.TDW.2h.1',
#  'CM334.Pc_CM.PC.TDW.2h.2',
#  'CM334.Pc_CM.PC.TDW.2h.3',
#  'CM334.Pc_CM.PC.TDW.4h.1',
#  'CM334.Pc_CM.PC.TDW.4h.2',
#  'CM334.Pc_CM.PC.TDW.4h.3',
#  'CM334.Pc_CM.PC.TDW.6h.1',
#  'CM334.Pc_CM.PC.TDW.6h.2',
#  'CM334.Pc_CM.PC.TDW.6h.3',
#  'CM334.Pc_CM.mc.1D.1',
#  'CM334.Pc_CM.mc.1D.2',
#  'CM334.Pc_CM.mc.1D.3',
#  'CM334.Pc_CM.mc.2D.1',
#  'CM334.Pc_CM.mc.2D.2',
#  'CM334.Pc_CM.mc.2D.3',
#  'CM334.PepMov_CM.Pep.1D.1',
#  'CM334.PepMov_CM.Pep.1D.2',
#  'CM334.PepMov_CM.Pep.1D.3',
#  'CM334.PepMov_CM.Pep.2D.1',
#  'CM334.PepMov_CM.Pep.2D.2',
#  'CM334.PepMov_CM.Pep.2D.3',
#  'CM334.PepMov_CM.Pep.30m.1',
#  'CM334.PepMov_CM.Pep.30m.2',
#  'CM334.PepMov_CM.Pep.30m.3',
#  'CM334.PepMov_CM.Pep.3D.1',
#  'CM334.PepMov_CM.Pep.3D.2',
#  'CM334.PepMov_CM.Pep.3D.3',
#  'CM334.PepMov_CM.Pep.4h.1',
#  'CM334.PepMov_CM.Pep.4h.2',
#  'CM334.PepMov_CM.Pep.4h.3',
#  'CM334.PepMov_CM.Pep.up.1',
#  'CM334.Pi_1.CM.pi.0.1',
#  'CM334.Pi_10.CM.pi.1D.1',
#  'CM334.Pi_11.CM.pi.1D.2',
#  'CM334.Pi_12.CM.pi.1D.3',
#  'CM334.Pi_13.CM.pi.3.5D.1',
#  'CM334.Pi_14.CM.pi.3.5D.2',
#  'CM334.Pi_15.CM.pi.3.5D.3',
#  'CM334.Pi_16.CM.pi.2D.1',
#  'CM334.Pi_17.CM.pi.2D.2',
#  'CM334.Pi_18.CM.pi.2D.3',
#  'CM334.Pi_19.CM.pi.5D.1',
#  'CM334.Pi_2.CM.pi.0.2',
#  'CM334.Pi_20.CM.pi.5D.2',
#  'CM334.Pi_21.CM.pi.5D.3',
#  'CM334.Pi_3.CM.pi.0.3',
#  'CM334.Pi_4.CM.pi.6h.1',
#  'CM334.Pi_5.CM.pi.6h.2',
#  'CM334.Pi_6.CM.pi.6h.3',
#  'CM334.Pi_7.CM.pi.12h.1',
#  'CM334.Pi_8.CM.pi.12h.2',
#  'CM334.Pi_9.CM.pi.12h.3',
#  'CM334.Pi_CM.TDW.12h.1',
#  'CM334.Pi_CM.TDW.12h.2',
#  'CM334.Pi_CM.TDW.12h.3',
#  'CM334.Pi_CM.TDW.1D.1',
#  'CM334.Pi_CM.TDW.1D.2',
#  'CM334.Pi_CM.TDW.1D.3',
#  'CM334.Pi_CM.TDW.2D.1',
#  'CM334.Pi_CM.TDW.2D.2',
#  'CM334.Pi_CM.TDW.2D.3',
#  'CM334.Pi_CM.TDW.3.5D.1',
#  'CM334.Pi_CM.TDW.3.5D.2',
#  'CM334.Pi_CM.TDW.3.5D.3',
#  'CM334.Pi_CM.TDW.5D.1',
#  'CM334.Pi_CM.TDW.5D.2',
#  'CM334.Pi_CM.TDW.5D.3',
#  'CM334.Pi_CM.TDW.6h.1',
#  'CM334.Pi_CM.TDW.6h.2',
#  'CM334.Pi_CM.TDW.6h.3',
#  'CM334.TMV_P0_CM.P0.1D.1',
#  'CM334.TMV_P0_CM.P0.1D.2',
#  'CM334.TMV_P0_CM.P0.1D.3',
#  'CM334.TMV_P0_CM.P0.2D.1',
#  'CM334.TMV_P0_CM.P0.2D.2',
#  'CM334.TMV_P0_CM.P0.2D.3',
#  'CM334.TMV_P0_CM.P0.30m.1',
#  'CM334.TMV_P0_CM.P0.30m.2',
#  'CM334.TMV_P0_CM.P0.30m.3',
#  'CM334.TMV_P0_CM.P0.3D.1',
#  'CM334.TMV_P0_CM.P0.3D.2',
#  'CM334.TMV_P0_CM.P0.3D.3',
#  'CM334.TMV_P0_CM.P0.4h.1',
#  'CM334.TMV_P0_CM.P0.4h.2',
#  'CM334.TMV_P0_CM.P0.4h.3',
#  'CM334.TMV_P0_CM.P0.up.1',
#  'CM334.TMV_P0_CM.P0.up.2',
#  'CM334.TMV_P0_CM.P0.up.3',
#  'CM334.TMV_P2_CM.P2.1D.1',
#  'CM334.TMV_P2_CM.P2.1D.2',
#  'CM334.TMV_P2_CM.P2.1D.3',
#  'CM334.TMV_P2_CM.P2.2D.1',
#  'CM334.TMV_P2_CM.P2.2D.2',
#  'CM334.TMV_P2_CM.P2.2D.3',
#  'CM334.TMV_P2_CM.P2.30m.1',
#  'CM334.TMV_P2_CM.P2.30m.2',
#  'CM334.TMV_P2_CM.P2.30m.3',
#  'CM334.TMV_P2_CM.P2.3D.2',
#  'CM334.TMV_P2_CM.P2.3D.2B',
#  'CM334.TMV_P2_CM.P2.3D.3',
#  'CM334.TMV_P2_CM.P2.4h.1',
#  'CM334.TMV_P2_CM.P2.4h.2',
#  'CM334.TMV_P2_CM.P2.4h.3',
#  'CM334.TMV_P2_CM.P2.up.3']

# %%
new_index = list(map(lambda x : x.replace("CM334.", ""), df.index))

# %%
new_index
# Out:
# ['Mock_CM.Mock.V.0.1',
#  'Mock_CM.Mock.V.0.2',
#  'Mock_CM.Mock.V.0.3',
#  'Mock_CM.Mock.V.1D.1',
#  'Mock_CM.Mock.V.1D.2',
#  'Mock_CM.Mock.V.1D.3',
#  'Mock_CM.Mock.V.2D.1',
#  'Mock_CM.Mock.V.2D.2',
#  'Mock_CM.Mock.V.2D.3',
#  'Mock_CM.Mock.V.30m.1',
#  'Mock_CM.Mock.V.30m.2',
#  'Mock_CM.Mock.V.30m.3',
#  'Mock_CM.Mock.V.3D.1',
#  'Mock_CM.Mock.V.3D.2',
#  'Mock_CM.Mock.V.3D.3',
#  'Mock_CM.Mock.V.4h.1',
#  'Mock_CM.Mock.V.4h.2',
#  'Mock_CM.Mock.V.4h.3',
#  'Mock_CM.Mock.V.up.1',
#  'Mock_CM.Mock.V.up.2',
#  'Pc_CM.0h.1',
#  'Pc_CM.0h.2',
#  'Pc_CM.0h.3',
#  'Pc_CM.PC.12h.1',
#  'Pc_CM.PC.12h.2',
#  'Pc_CM.PC.12h.3',
#  'Pc_CM.PC.1D.1',
#  'Pc_CM.PC.1D.2',
#  'Pc_CM.PC.1D.3',
#  'Pc_CM.PC.1h.1',
#  'Pc_CM.PC.1h.2',
#  'Pc_CM.PC.1h.3',
#  'Pc_CM.PC.2h.1',
#  'Pc_CM.PC.2h.2',
#  'Pc_CM.PC.2h.3',
#  'Pc_CM.PC.4h.1',
#  'Pc_CM.PC.4h.2',
#  'Pc_CM.PC.4h.3',
#  'Pc_CM.PC.6h.1',
#  'Pc_CM.PC.6h.2',
#  'Pc_CM.PC.6h.3',
#  'Pc_CM.PC.TDW.12h.1',
#  'Pc_CM.PC.TDW.12h.2',
#  'Pc_CM.PC.TDW.12h.3',
#  'Pc_CM.PC.TDW.1D.1',
#  'Pc_CM.PC.TDW.1D.2',
#  'Pc_CM.PC.TDW.1D.3',
#  'Pc_CM.PC.TDW.1h.1',
#  'Pc_CM.PC.TDW.1h.2',
#  'Pc_CM.PC.TDW.1h.3',
#  'Pc_CM.PC.TDW.2h.1',
#  'Pc_CM.PC.TDW.2h.2',
#  'Pc_CM.PC.TDW.2h.3',
#  'Pc_CM.PC.TDW.4h.1',
#  'Pc_CM.PC.TDW.4h.2',
#  'Pc_CM.PC.TDW.4h.3',
#  'Pc_CM.PC.TDW.6h.1',
#  'Pc_CM.PC.TDW.6h.2',
#  'Pc_CM.PC.TDW.6h.3',
#  'Pc_CM.mc.1D.1',
#  'Pc_CM.mc.1D.2',
#  'Pc_CM.mc.1D.3',
#  'Pc_CM.mc.2D.1',
#  'Pc_CM.mc.2D.2',
#  'Pc_CM.mc.2D.3',
#  'PepMov_CM.Pep.1D.1',
#  'PepMov_CM.Pep.1D.2',
#  'PepMov_CM.Pep.1D.3',
#  'PepMov_CM.Pep.2D.1',
#  'PepMov_CM.Pep.2D.2',
#  'PepMov_CM.Pep.2D.3',
#  'PepMov_CM.Pep.30m.1',
#  'PepMov_CM.Pep.30m.2',
#  'PepMov_CM.Pep.30m.3',
#  'PepMov_CM.Pep.3D.1',
#  'PepMov_CM.Pep.3D.2',
#  'PepMov_CM.Pep.3D.3',
#  'PepMov_CM.Pep.4h.1',
#  'PepMov_CM.Pep.4h.2',
#  'PepMov_CM.Pep.4h.3',
#  'PepMov_CM.Pep.up.1',
#  'Pi_1.CM.pi.0.1',
#  'Pi_10.CM.pi.1D.1',
#  'Pi_11.CM.pi.1D.2',
#  'Pi_12.CM.pi.1D.3',
#  'Pi_13.CM.pi.3.5D.1',
#  'Pi_14.CM.pi.3.5D.2',
#  'Pi_15.CM.pi.3.5D.3',
#  'Pi_16.CM.pi.2D.1',
#  'Pi_17.CM.pi.2D.2',
#  'Pi_18.CM.pi.2D.3',
#  'Pi_19.CM.pi.5D.1',
#  'Pi_2.CM.pi.0.2',
#  'Pi_20.CM.pi.5D.2',
#  'Pi_21.CM.pi.5D.3',
#  'Pi_3.CM.pi.0.3',
#  'Pi_4.CM.pi.6h.1',
#  'Pi_5.CM.pi.6h.2',
#  'Pi_6.CM.pi.6h.3',
#  'Pi_7.CM.pi.12h.1',
#  'Pi_8.CM.pi.12h.2',
#  'Pi_9.CM.pi.12h.3',
#  'Pi_CM.TDW.12h.1',
#  'Pi_CM.TDW.12h.2',
#  'Pi_CM.TDW.12h.3',
#  'Pi_CM.TDW.1D.1',
#  'Pi_CM.TDW.1D.2',
#  'Pi_CM.TDW.1D.3',
#  'Pi_CM.TDW.2D.1',
#  'Pi_CM.TDW.2D.2',
#  'Pi_CM.TDW.2D.3',
#  'Pi_CM.TDW.3.5D.1',
#  'Pi_CM.TDW.3.5D.2',
#  'Pi_CM.TDW.3.5D.3',
#  'Pi_CM.TDW.5D.1',
#  'Pi_CM.TDW.5D.2',
#  'Pi_CM.TDW.5D.3',
#  'Pi_CM.TDW.6h.1',
#  'Pi_CM.TDW.6h.2',
#  'Pi_CM.TDW.6h.3',
#  'TMV_P0_CM.P0.1D.1',
#  'TMV_P0_CM.P0.1D.2',
#  'TMV_P0_CM.P0.1D.3',
#  'TMV_P0_CM.P0.2D.1',
#  'TMV_P0_CM.P0.2D.2',
#  'TMV_P0_CM.P0.2D.3',
#  'TMV_P0_CM.P0.30m.1',
#  'TMV_P0_CM.P0.30m.2',
#  'TMV_P0_CM.P0.30m.3',
#  'TMV_P0_CM.P0.3D.1',
#  'TMV_P0_CM.P0.3D.2',
#  'TMV_P0_CM.P0.3D.3',
#  'TMV_P0_CM.P0.4h.1',
#  'TMV_P0_CM.P0.4h.2',
#  'TMV_P0_CM.P0.4h.3',
#  'TMV_P0_CM.P0.up.1',
#  'TMV_P0_CM.P0.up.2',
#  'TMV_P0_CM.P0.up.3',
#  'TMV_P2_CM.P2.1D.1',
#  'TMV_P2_CM.P2.1D.2',
#  'TMV_P2_CM.P2.1D.3',
#  'TMV_P2_CM.P2.2D.1',
#  'TMV_P2_CM.P2.2D.2',
#  'TMV_P2_CM.P2.2D.3',
#  'TMV_P2_CM.P2.30m.1',
#  'TMV_P2_CM.P2.30m.2',
#  'TMV_P2_CM.P2.30m.3',
#  'TMV_P2_CM.P2.3D.2',
#  'TMV_P2_CM.P2.3D.2B',
#  'TMV_P2_CM.P2.3D.3',
#  'TMV_P2_CM.P2.4h.1',
#  'TMV_P2_CM.P2.4h.2',
#  'TMV_P2_CM.P2.4h.3',
#  'TMV_P2_CM.P2.up.3']

# %%
new_index = [
 'Mock.0.1',
 'Mock.0.2',
 'Mock.0.3',
 'Mock.1D.1',
 'Mock.1D.2',
 'Mock.1D.3',
 'Mock.2D.1',
 'Mock.2D.2',
 'Mock.2D.3',
 'Mock.30m.1',
 'Mock.30m.2',
 'Mock.30m.3',
 'Mock.3D.1',
 'Mock.3D.2',
 'Mock.3D.3',
 'Mock.4h.1',
 'Mock.4h.2',
 'Mock.4h.3',
 'Mock.up.1',
 'Mock.up.2',
 'Pc.0.1',
 'Pc.0.2',
 'Pc.0.3',
 'Pc.12h.1',
 'Pc.12h.2',
 'Pc.12h.3',
 'Pc.1D.1',
 'Pc.1D.2',
 'Pc.1D.3',
 'Pc.1h.1',
 'Pc.1h.2',
 'Pc.1h.3',
 'Pc.2h.1',
 'Pc.2h.2',
 'Pc.2h.3',
 'Pc.4h.1',
 'Pc.4h.2',
 'Pc.4h.3',
 'Pc.6h.1',
 'Pc.6h.2',
 'Pc.6h.3',
 'Pc.TDW.12h.1',
 'Pc.TDW.12h.2',
 'Pc.TDW.12h.3',
 'Pc.TDW.1D.1',
 'Pc.TDW.1D.2',
 'Pc.TDW.1D.3',
 'Pc.TDW.1h.1',
 'Pc.TDW.1h.2',
 'Pc.TDW.1h.3',
 'Pc.TDW.2h.1',
 'Pc.TDW.2h.2',
 'Pc.TDW.2h.3',
 'Pc.TDW.4h.1',
 'Pc.TDW.4h.2',
 'Pc.TDW.4h.3',
 'Pc.TDW.6h.1',
 'Pc.TDW.6h.2',
 'Pc.TDW.6h.3',
 'Pc.mc.1D.1',
 'Pc.mc.1D.2',
 'Pc.mc.1D.3',
 'Pc.mc.2D.1',
 'Pc.mc.2D.2',
 'Pc.mc.2D.3',
 'PepMov.1D.1',
 'PepMov.1D.2',
 'PepMov.1D.3',
 'PepMov.2D.1',
 'PepMov.2D.2',
 'PepMov.2D.3',
 'PepMov.30m.1',
 'PepMov.30m.2',
 'PepMov.30m.3',
 'PepMov.3D.1',
 'PepMov.3D.2',
 'PepMov.3D.3',
 'PepMov.4h.1',
 'PepMov.4h.2',
 'PepMov.4h.3',
 'PepMov.up.1',
 'Pi.0.1',
 'Pi.1D.1',
 'Pi.1D.2',
 'Pi.1D.3',
 'Pi.3.5D.1',
 'Pi.3.5D.2',
 'Pi.3.5D.3',
 'Pi.2D.1',
 'Pi.2D.2',
 'Pi.2D.3',
 'Pi.5D.1',
 'Pi.0.2',
 'Pi.5D.2',
 'Pi.5D.3',
 'Pi.0.3',
 'Pi.6h.1',
 'Pi.6h.2',
 'Pi.6h.3',
 'Pi.12h.1',
 'Pi.12h.2',
 'Pi.12h.3',
 'Pi.TDW.12h.1',
 'Pi.TDW.12h.2',
 'Pi.TDW.12h.3',
 'Pi.TDW.1D.1',
 'Pi.TDW.1D.2',
 'Pi.TDW.1D.3',
 'Pi.TDW.2D.1',
 'Pi.TDW.2D.2',
 'Pi.TDW.2D.3',
 'Pi.TDW.3.5D.1',
 'Pi.TDW.3.5D.2',
 'Pi.TDW.3.5D.3',
 'Pi.TDW.5D.1',
 'Pi.TDW.5D.2',
 'Pi.TDW.5D.3',
 'Pi.TDW.6h.1',
 'Pi.TDW.6h.2',
 'Pi.TDW.6h.3',
 'TMV_P0.1D.1',
 'TMV_P0.1D.2',
 'TMV_P0.1D.3',
 'TMV_P0.2D.1',
 'TMV_P0.2D.2',
 'TMV_P0.2D.3',
 'TMV_P0.30m.1',
 'TMV_P0.30m.2',
 'TMV_P0.30m.3',
 'TMV_P0.3D.1',
 'TMV_P0.3D.2',
 'TMV_P0.3D.3',
 'TMV_P0.4h.1',
 'TMV_P0.4h.2',
 'TMV_P0.4h.3',
 'TMV_P0.up.1',
 'TMV_P0.up.2',
 'TMV_P0.up.3',
 'TMV_P2.1D.1',
 'TMV_P2.1D.2',
 'TMV_P2.1D.3',
 'TMV_P2.2D.1',
 'TMV_P2.2D.2',
 'TMV_P2.2D.3',
 'TMV_P2.30m.1',
 'TMV_P2.30m.2',
 'TMV_P2.30m.3',
 'TMV_P2.3D.1',
 'TMV_P2.3D.2',
 'TMV_P2.3D.3',
 'TMV_P2.4h.1',
 'TMV_P2.4h.2',
 'TMV_P2.4h.3',
 'TMV_P2.up.3']

# %%
df.index = new_index

# %%
df.head(1)
# Out:
#            MEblack    MEblue   MEbrown  MEbrown4    MEcyan  MEdarkgreen  \
# Mock.0.1  0.020694 -0.051823 -0.043303  0.004311 -0.025367     -0.03813
#
#           MEdarkgrey  MEdarkmagenta  MEdarkolivegreen  MEdarkorange  ...  \
# Mock.0.1   -0.010358      -0.010666         -0.013568     -0.010313  ...
#
#           MEsienna3  MEskyblue  MEskyblue3  MEsteelblue     MEtan  \
# Mock.0.1  -0.009348  -0.009556   -0.006561     -0.01205 -0.013461
#
#           MEturquoise  MEviolet   MEwhite  MEyellow  MEyellowgreen
# Mock.0.1     -0.07648 -0.009893 -0.012231 -0.051104      -0.012645
#
# [1 rows x 47 columns]

# %%
idx = [
 'Mock.0.1',
 'Mock.0.2',
 'Mock.0.3',
 'Mock.30m.1',
 'Mock.30m.2',
 'Mock.30m.3',    
 'Mock.1D.1',
 'Mock.1D.2',
 'Mock.1D.3',
 'Mock.2D.1',
 'Mock.2D.2',
 'Mock.2D.3',
 'Mock.3D.1',
 'Mock.3D.2',
 'Mock.3D.3',
 'Mock.4h.1',
 'Mock.4h.2',
 'Mock.4h.3',
 'Mock.up.1',
 'Mock.up.2',
 'TMV_P0.30m.1',
 'TMV_P0.30m.2',
 'TMV_P0.30m.3',    
 'TMV_P0.4h.1',
 'TMV_P0.4h.2',
 'TMV_P0.4h.3',    
 'TMV_P0.1D.1',
 'TMV_P0.1D.2',
 'TMV_P0.1D.3',
 'TMV_P0.2D.1',
 'TMV_P0.2D.2',
 'TMV_P0.2D.3',
 'TMV_P0.3D.1',
 'TMV_P0.3D.2',
 'TMV_P0.3D.3',
 'TMV_P0.up.1',
 'TMV_P0.up.2',
 'TMV_P0.up.3',
 'TMV_P2.30m.1',
 'TMV_P2.30m.2',
 'TMV_P2.30m.3',    
 'TMV_P2.4h.1',
 'TMV_P2.4h.2',
 'TMV_P2.4h.3',    
 'TMV_P2.1D.1',
 'TMV_P2.1D.2',
 'TMV_P2.1D.3',
 'TMV_P2.2D.1',
 'TMV_P2.2D.2',
 'TMV_P2.2D.3',
 'TMV_P2.3D.1',
 'TMV_P2.3D.2',
 'TMV_P2.3D.3',
 'TMV_P2.up.3',
 'PepMov.30m.1',
 'PepMov.30m.2',
 'PepMov.30m.3',   
 'PepMov.4h.1',
 'PepMov.4h.2',
 'PepMov.4h.3',    
 'PepMov.1D.1',
 'PepMov.1D.2',
 'PepMov.1D.3',
 'PepMov.2D.1',
 'PepMov.2D.2',
 'PepMov.2D.3',
 'PepMov.3D.1',
 'PepMov.3D.2',
 'PepMov.3D.3',
 'PepMov.up.1',    
 'Pi.0.1',
 'Pi.0.2',    
 'Pi.0.3',    
 'Pi.TDW.6h.1',
 'Pi.TDW.6h.2',
 'Pi.TDW.6h.3',
 'Pi.TDW.12h.1',
 'Pi.TDW.12h.2',
 'Pi.TDW.12h.3',
 'Pi.TDW.1D.1',
 'Pi.TDW.1D.2',
 'Pi.TDW.1D.3',
 'Pi.TDW.2D.1',
 'Pi.TDW.2D.2',
 'Pi.TDW.2D.3',
 'Pi.TDW.3.5D.1',
 'Pi.TDW.3.5D.2',
 'Pi.TDW.3.5D.3',
 'Pi.TDW.5D.1',
 'Pi.TDW.5D.2',
 'Pi.TDW.5D.3',  
 'Pi.6h.1',
 'Pi.6h.2',
 'Pi.6h.3',
 'Pi.12h.1',
 'Pi.12h.2',
 'Pi.12h.3',    
 'Pi.1D.1',
 'Pi.1D.2',
 'Pi.1D.3',
 'Pi.2D.1',
 'Pi.2D.2',
 'Pi.2D.3',    
 'Pi.3.5D.1',
 'Pi.3.5D.2',
 'Pi.3.5D.3',
 'Pi.5D.1',
 'Pi.5D.2',
 'Pi.5D.3',
 'Pc.TDW.1h.1',
 'Pc.TDW.1h.2',
 'Pc.TDW.1h.3',
 'Pc.TDW.2h.1',
 'Pc.TDW.2h.2',
 'Pc.TDW.2h.3',
 'Pc.TDW.4h.1',
 'Pc.TDW.4h.2',
 'Pc.TDW.4h.3',
 'Pc.TDW.6h.1',
 'Pc.TDW.6h.2',
 'Pc.TDW.6h.3',    
 'Pc.TDW.12h.1',
 'Pc.TDW.12h.2',
 'Pc.TDW.12h.3',
 'Pc.TDW.1D.1',
 'Pc.TDW.1D.2',
 'Pc.TDW.1D.3',    
 'Pc.0.1',
 'Pc.0.2',
 'Pc.0.3',
 'Pc.1h.1',
 'Pc.1h.2',
 'Pc.1h.3',
 'Pc.2h.1',
 'Pc.2h.2',
 'Pc.2h.3',
 'Pc.4h.1',
 'Pc.4h.2',
 'Pc.4h.3',
 'Pc.6h.1',
 'Pc.6h.2',
 'Pc.6h.3',    
 'Pc.12h.1',
 'Pc.12h.2',
 'Pc.12h.3',
 'Pc.1D.1',
 'Pc.1D.2',
 'Pc.1D.3',
 'Pc.mc.1D.1',
 'Pc.mc.1D.2',
 'Pc.mc.1D.3',
 'Pc.mc.2D.1',
 'Pc.mc.2D.2',
 'Pc.mc.2D.3'
]

# %%
df_reindex = df.reindex(idx)

# %%
df_reindex
# Out:
#              MEblack    MEblue   MEbrown  MEbrown4    MEcyan  MEdarkgreen  \
# Mock.0.1    0.020694 -0.051823 -0.043303  0.004311 -0.025367    -0.038130
# Mock.0.2    0.059589 -0.054156 -0.045673 -0.009789 -0.025888    -0.038065
# Mock.0.3    0.083611 -0.050684 -0.043368 -0.002902 -0.023829    -0.033430
# Mock.30m.1  0.044004 -0.048184 -0.035163  0.023598 -0.024752    -0.023921
# Mock.30m.2  0.057034 -0.049911 -0.034556 -0.001768 -0.022740    -0.037959
# ...              ...       ...       ...       ...       ...          ...
# Pc.mc.1D.2 -0.099314 -0.033643 -0.023873 -0.014231 -0.017395    -0.007742
# Pc.mc.1D.3 -0.099415 -0.033477 -0.023795 -0.008015 -0.018782    -0.012714
# Pc.mc.2D.1 -0.127783 -0.027600 -0.009038 -0.007547  0.013269     0.047908
# Pc.mc.2D.2 -0.132102 -0.027052 -0.007706 -0.012335  0.021771     0.064073
# Pc.mc.2D.3 -0.132318 -0.026400 -0.007438 -0.017011  0.015691     0.056171
#
#             MEdarkgrey  MEdarkmagenta  MEdarkolivegreen  MEdarkorange  ...  \
# Mock.0.1     -0.010358      -0.010666         -0.013568     -0.010313  ...
# Mock.0.2     -0.010358      -0.010666         -0.013520     -0.010313  ...
# Mock.0.3     -0.009578      -0.010666         -0.002195     -0.010313  ...
# Mock.30m.1   -0.009547      -0.010666          0.004994     -0.010313  ...
# Mock.30m.2   -0.010358      -0.010666         -0.003164      0.003654  ...
# ...                ...            ...               ...           ...  ...
# Pc.mc.1D.2   -0.010358      -0.010666         -0.005716      0.002192  ...
# Pc.mc.1D.3    0.002367      -0.010666         -0.014512     -0.010313  ...
# Pc.mc.2D.1   -0.010358      -0.010666         -0.014512     -0.010313  ...
# Pc.mc.2D.2   -0.009002      -0.010666         -0.014512     -0.010313  ...
# Pc.mc.2D.3   -0.010358      -0.010666         -0.007858     -0.010313  ...
#
#             MEsienna3  MEskyblue  MEskyblue3  MEsteelblue     MEtan  \
# Mock.0.1    -0.009348  -0.009556   -0.006561     -0.01205 -0.013461
# Mock.0.2    -0.009348  -0.009556   -0.017962     -0.01205 -0.014795
# Mock.0.3     0.004253  -0.003639   -0.008117     -0.01205 -0.010067
# Mock.30m.1  -0.009348  -0.009556   -0.012902      0.00978 -0.011741
# Mock.30m.2  -0.009348  -0.009556   -0.004528     -0.01205 -0.008409
# ...               ...        ...         ...          ...       ...
# Pc.mc.1D.2  -0.009348  -0.009556   -0.013394     -0.01205 -0.011050
# Pc.mc.1D.3  -0.009348  -0.009556   -0.009450     -0.01205 -0.014795
# Pc.mc.2D.1  -0.009348  -0.009556    0.007211     -0.01205 -0.009586
# Pc.mc.2D.2  -0.009348  -0.009556    0.008099     -0.01205 -0.014795
# Pc.mc.2D.3  -0.003203  -0.009556    0.001048     -0.01205 -0.012015
#
#             MEturquoise  MEviolet   MEwhite  MEyellow  MEyellowgreen
# Mock.0.1      -0.076480 -0.009893 -0.012231 -0.051104      -0.012645
# Mock.0.2      -0.081981 -0.000538 -0.006823 -0.056177      -0.007794
# Mock.0.3      -0.073400 -0.002313 -0.005744 -0.047443       0.010558
# Mock.30m.1    -0.078941 -0.011433 -0.011407 -0.054254      -0.008078
# Mock.30m.2    -0.080705  0.013447 -0.005095 -0.051237       0.008282
# ...                 ...       ...       ...       ...            ...
# Pc.mc.1D.2    -0.015557 -0.011433 -0.004935 -0.038290      -0.009426
# Pc.mc.1D.3    -0.014286 -0.011433  0.002587 -0.037610      -0.011627
# Pc.mc.2D.1     0.034286 -0.011433  0.031516  0.009796       0.002730
# Pc.mc.2D.2     0.035671 -0.011433  0.033212  0.008574       0.058288
# Pc.mc.2D.3     0.034745 -0.011433  0.988724  0.011131       0.010391
#
# [154 rows x 47 columns]

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEbrown4',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkmagenta',
#  'MEdarkolivegreen',
#  'MEdarkorange',
#  'MEdarkorange2',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEfloralwhite',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MEivory',
#  'MElightcyan',
#  'MElightcyan1',
#  'MElightgreen',
#  'MElightsteelblue1',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmediumpurple3',
#  'MEmidnightblue',
#  'MEorange',
#  'MEorangered4',
#  'MEpaleturquoise',
#  'MEpink',
#  'MEplum1',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsaddlebrown',
#  'MEsalmon',
#  'MEsienna3',
#  'MEskyblue',
#  'MEskyblue3',
#  'MEsteelblue',
#  'MEtan',
#  'MEturquoise',
#  'MEviolet',
#  'MEwhite',
#  'MEyellow',
#  'MEyellowgreen']

# %%
col = [
 'MEgrey',
 'MEturquoise',
 'MEyellow', 
 'MElightcyan',    
 'MEblack',
 'MEred',    
 'MEdarkgreen',     
 'MEgreen', 
 'MEpurple',  
 'MEmagenta',     
 'MEsalmon',
      
 'MEbrown',       
 'MEblue',
 'MEpink',
 'MEcyan',
    
    
 'MEbrown4',


 'MEdarkgrey',
 'MEdarkmagenta',
 'MEdarkolivegreen',
 'MEdarkorange',
 'MEdarkorange2',
 'MEdarkred',
 'MEdarkturquoise',
 'MEfloralwhite',

 'MEgreenyellow',

 'MEgrey60',
 'MEivory',

 'MElightcyan1',
 'MElightgreen',
 'MElightsteelblue1',
 'MElightyellow',

    
 'MEmediumpurple3',
 'MEmidnightblue',
 'MEorange',
 'MEorangered4',
 'MEpaleturquoise',

 'MEplum1',


 'MEroyalblue',
 'MEsaddlebrown',

 'MEsienna3',
 'MEskyblue',
 'MEskyblue3',
 'MEsteelblue',
 'MEtan',
   
 'MEviolet',
 'MEwhite',

 'MEyellowgreen']

# %%
df_reindex = df_reindex[col]

# %%
plt.figure(figsize = (30, 50))
sns.set(font_scale = 1)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
plt.title('Module-sample relationships', fontsize = 30)
# plt.savefig('Module-sample relationships.CM334.Mock.png')
# plt.savefig('Module-sample relationships.jpg')
# plt.savefig('Module-sample relationships.pdf')
plt.show()

# %%
[ 
 'Pc.0.1',
 'Pc.0.2',
 'Pc.0.3', 
 'Pc.TDW.1h.1',
 'Pc.TDW.1h.2',
 'Pc.TDW.1h.3',
 'Pc.TDW.2h.1',
 'Pc.TDW.2h.2',
 'Pc.TDW.2h.3',
 'Pc.TDW.4h.1',
 'Pc.TDW.4h.2',
 'Pc.TDW.4h.3',
 'Pc.TDW.6h.1',
 'Pc.TDW.6h.2',
 'Pc.TDW.6h.3',    
 'Pc.TDW.12h.1',
 'Pc.TDW.12h.2',
 'Pc.TDW.12h.3',
 'Pc.TDW.1D.1',
 'Pc.TDW.1D.2',
 'Pc.TDW.1D.3',    
 'Pc.1h.1',
 'Pc.1h.2',
 'Pc.1h.3',
 'Pc.2h.1',
 'Pc.2h.2',
 'Pc.2h.3',
 'Pc.4h.1',
 'Pc.4h.2',
 'Pc.4h.3',
 'Pc.6h.1',
 'Pc.6h.2',
 'Pc.6h.3',    
 'Pc.12h.1',
 'Pc.12h.2',
 'Pc.12h.3',
 'Pc.1D.1',
 'Pc.1D.2',
 'Pc.1D.3',
 'Pc.mc.1D.1',
 'Pc.mc.1D.2',
 'Pc.mc.1D.3',
 'Pc.mc.2D.1',
 'Pc.mc.2D.2',
 'Pc.mc.2D.3']
# Out:
# ['Pc.0.1',
#  'Pc.0.2',
#  'Pc.0.3',
#  'Pc.TDW.1h.1',
#  'Pc.TDW.1h.2',
#  'Pc.TDW.1h.3',
#  'Pc.TDW.2h.1',
#  'Pc.TDW.2h.2',
#  'Pc.TDW.2h.3',
#  'Pc.TDW.4h.1',
#  'Pc.TDW.4h.2',
#  'Pc.TDW.4h.3',
#  'Pc.TDW.6h.1',
#  'Pc.TDW.6h.2',
#  'Pc.TDW.6h.3',
#  'Pc.TDW.12h.1',
#  'Pc.TDW.12h.2',
#  'Pc.TDW.12h.3',
#  'Pc.TDW.1D.1',
#  'Pc.TDW.1D.2',
#  'Pc.TDW.1D.3',
#  'Pc.1h.1',
#  'Pc.1h.2',
#  'Pc.1h.3',
#  'Pc.2h.1',
#  'Pc.2h.2',
#  'Pc.2h.3',
#  'Pc.4h.1',
#  'Pc.4h.2',
#  'Pc.4h.3',
#  'Pc.6h.1',
#  'Pc.6h.2',
#  'Pc.6h.3',
#  'Pc.12h.1',
#  'Pc.12h.2',
#  'Pc.12h.3',
#  'Pc.1D.1',
#  'Pc.1D.2',
#  'Pc.1D.3',
#  'Pc.mc.1D.1',
#  'Pc.mc.1D.2',
#  'Pc.mc.1D.3',
#  'Pc.mc.2D.1',
#  'Pc.mc.2D.2',
#  'Pc.mc.2D.3']

# %%
[ 
 'Pi.0.1',
 'Pi.0.2',    
 'Pi.0.3',
 'Pi.TDW.6h.1',
 'Pi.TDW.6h.2',
 'Pi.TDW.6h.3',
 'Pi.TDW.12h.1',
 'Pi.TDW.12h.2',
 'Pi.TDW.12h.3',
 'Pi.TDW.1D.1',
 'Pi.TDW.1D.2',
 'Pi.TDW.1D.3',
 'Pi.TDW.2D.1',
 'Pi.TDW.2D.2',
 'Pi.TDW.2D.3',
 'Pi.TDW.3.5D.1',
 'Pi.TDW.3.5D.2',
 'Pi.TDW.3.5D.3',
 'Pi.TDW.5D.1',
 'Pi.TDW.5D.2',
 'Pi.TDW.5D.3',    
 'Pi.6h.1',
 'Pi.6h.2',
 'Pi.6h.3',
 'Pi.12h.1',
 'Pi.12h.2',
 'Pi.12h.3',    
 'Pi.1D.1',
 'Pi.1D.2',
 'Pi.1D.3',
 'Pi.2D.1',
 'Pi.2D.2',
 'Pi.2D.3',    
 'Pi.3.5D.1',
 'Pi.3.5D.2',
 'Pi.3.5D.3',
 'Pi.5D.1',
 'Pi.5D.2',
 'Pi.5D.3',
]

# %%
[ 
 'Mock.0.1',
 'Mock.0.2',
 'Mock.0.3',
 'Mock.30m.1',
 'Mock.30m.2',
 'Mock.30m.3',   
 'Mock.4h.1',
 'Mock.4h.2',
 'Mock.4h.3',    
 'Mock.1D.1',
 'Mock.1D.2',
 'Mock.1D.3',
 'Mock.2D.1',
 'Mock.2D.2',
 'Mock.2D.3',
 'Mock.3D.1',
 'Mock.3D.2',
 'Mock.3D.3',
 'Mock.up.1',
 'Mock.up.2',
 'PepMov.30m.1',
 'PepMov.30m.2',
 'PepMov.30m.3',   
 'PepMov.4h.1',
 'PepMov.4h.2',
 'PepMov.4h.3',    
 'PepMov.1D.1',
 'PepMov.1D.2',
 'PepMov.1D.3',
 'PepMov.2D.1',
 'PepMov.2D.2',
 'PepMov.2D.3',
 'PepMov.3D.1',
 'PepMov.3D.2',
 'PepMov.3D.3',
 'PepMov.up.1'
]

# %%
[
 'Mock.0.1',
 'Mock.0.2',
 'Mock.0.3',
 'Mock.30m.1',
 'Mock.30m.2',
 'Mock.30m.3',    
 'Mock.4h.1',
 'Mock.4h.2',
 'Mock.4h.3',    
 'Mock.1D.1',
 'Mock.1D.2',
 'Mock.1D.3',
 'Mock.2D.1',
 'Mock.2D.2',
 'Mock.2D.3',
 'Mock.3D.1',
 'Mock.3D.2',
 'Mock.3D.3',
 'Mock.up.1',
 'Mock.up.2',
 'TMV_P0.30m.1',
 'TMV_P0.30m.2',
 'TMV_P0.30m.3',    
 'TMV_P0.4h.1',
 'TMV_P0.4h.2',
 'TMV_P0.4h.3',    
 'TMV_P0.1D.1',
 'TMV_P0.1D.2',
 'TMV_P0.1D.3',
 'TMV_P0.2D.1',
 'TMV_P0.2D.2',
 'TMV_P0.2D.3',
 'TMV_P0.3D.1',
 'TMV_P0.3D.2',
 'TMV_P0.3D.3',
 'TMV_P0.up.1',
 'TMV_P0.up.2',
 'TMV_P0.up.3',
]

# %%
[
 'Mock.0.1',
 'Mock.0.2',
 'Mock.0.3',
 'Mock.30m.1',
 'Mock.30m.2',
 'Mock.30m.3',   
 'Mock.4h.1',
 'Mock.4h.2',
 'Mock.4h.3',    
 'Mock.1D.1',
 'Mock.1D.2',
 'Mock.1D.3',
 'Mock.2D.1',
 'Mock.2D.2',
 'Mock.2D.3',
 'Mock.3D.1',
 'Mock.3D.2',
 'Mock.3D.3',
 'Mock.up.1',
 'Mock.up.2',
 'TMV_P2.30m.1',
 'TMV_P2.30m.2',
 'TMV_P2.30m.3',    
 'TMV_P2.4h.1',
 'TMV_P2.4h.2',
 'TMV_P2.4h.3',    
 'TMV_P2.1D.1',
 'TMV_P2.1D.2',
 'TMV_P2.1D.3',
 'TMV_P2.2D.1',
 'TMV_P2.2D.2',
 'TMV_P2.2D.3',
 'TMV_P2.3D.1',
 'TMV_P2.3D.2',
 'TMV_P2.3D.3',
 'TMV_P2.up.3'
]
