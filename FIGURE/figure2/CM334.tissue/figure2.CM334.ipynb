# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("MEs.new.txt", sep = '\t')

# %%
df.head(1)
# Out:
#               MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# CM.Flo.1..4  0.014268  0.003678 -0.002721 -0.076005     0.074704   -0.022707
#
#              MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# CM.Flo.1..4      -0.002612          0.041155     -0.029108   0.052724  ...
#
#              MEsienna3  MEskyblue  MEskyblue3  MEsteelblue     MEtan  \
# CM.Flo.1..4    0.02635   0.028493     0.03146     0.045318  0.983977
#
#              MEturquoise  MEviolet   MEwhite  MEyellow  MEyellowgreen
# CM.Flo.1..4     0.697384    0.0202  0.017334 -0.025441       0.054865
#
# [1 rows x 43 columns]

# %%
list(df.index)
# Out:
# ['CM.Flo.1..4',
#  'CM.Flo.2..5',
#  'Leaf2',
#  'Leaf3',
#  'Leaf4',
#  'PL1.1',
#  'PL1.2',
#  'PL1.3',
#  'PL2.1',
#  'PL2.2',
#  'PL2.3',
#  'PL3.1',
#  'PL3.2',
#  'PL3.3',
#  'PLB.1',
#  'PLB.2',
#  'PLB.3',
#  'PLBplus10.1',
#  'PLBplus10.2',
#  'PLBplus10.3',
#  'PLBplus5.1',
#  'PLBplus5.2',
#  'PLBplus5.3',
#  'PLMG.1',
#  'PLMG.2',
#  'PLMG.3',
#  'root.1',
#  'root.2',
#  'root.3',
#  'stem.1',
#  'stem.2',
#  'stem.3']

# %%
new_index = [
 'flower-1',
 'flower-2',
 'leaf-2',
 'leaf-3',
 'leaf-4',
 'PL1-1',
 'PL1-2',
 'PL1-3',
 'PL2-1',
 'PL2-2',
 'PL2-3',
 'PL3-1',
 'PL3-2',
 'PL3-3',
 'PLB-1',
 'PLB-2',
 'PLB-3',
 'PLB10-1',
 'PLB10-2',
 'PLB10-3',
 'PLB5-1',
 'PLB5-2',
 'PLB5-3',
 'PLMG-1',
 'PLMG-2',
 'PLMG-3',
 'root-1',
 'root-2',
 'root-3',
 'stem-1',
 'stem-2',
 'stem-3']

# %%
df.index = new_index

# %%
df.head(1)
# Out:
#            MEblack    MEblue   MEbrown    MEcyan  MEdarkgreen  MEdarkgrey  \
# flower-1  0.014268  0.003678 -0.002721 -0.076005     0.074704   -0.022707
#
#           MEdarkmagenta  MEdarkolivegreen  MEdarkorange  MEdarkred  ...  \
# flower-1      -0.002612          0.041155     -0.029108   0.052724  ...
#
#           MEsienna3  MEskyblue  MEskyblue3  MEsteelblue     MEtan  \
# flower-1    0.02635   0.028493     0.03146     0.045318  0.983977
#
#           MEturquoise  MEviolet   MEwhite  MEyellow  MEyellowgreen
# flower-1     0.697384    0.0202  0.017334 -0.025441       0.054865
#
# [1 rows x 43 columns]

# %%
idx = [
 'root-1',
 'root-2',
 'root-3',
 'stem-1',
 'stem-2',
 'stem-3', 
 'leaf-2',
 'leaf-3',
 'leaf-4',
 'flower-1',
 'flower-2',
 'PL1-1',
 'PL1-2',
 'PL1-3',
 'PL2-1',
# PLMG-3      -0.040505 -0.050385 -0.019107  0.046024      -0.043530
# PLB-1       -0.055183 -0.004938 -0.015408  0.012578      -0.030497
# PLB-2       -0.058805 -0.050379 -0.034430  0.019343      -0.045922
# PLB-3       -0.038742 -0.051012 -0.009670  0.122505      -0.048718
# PLB5-1      -0.053802 -0.015696 -0.057313  0.231208      -0.017037
# PLB5-2      -0.036607 -0.004256 -0.028601  0.256213      -0.018938
# PLB5-3      -0.042082 -0.015050 -0.007372  0.236011      -0.032566
# PLB10-1     -0.046842  0.014870 -0.022448  0.393696      -0.005636
# PLB10-2     -0.050995  0.977584 -0.032241  0.425903      -0.001984
# PLB10-3     -0.050035  0.007818 -0.056938  0.405176       0.977193
#
# [32 rows x 43 columns]

# %%
list(df.columns)
# Out:
# ['MEblack',
#  'MEblue',
#  'MEbrown',
#  'MEcyan',
#  'MEdarkgreen',
#  'MEdarkgrey',
#  'MEdarkmagenta',
#  'MEdarkolivegreen',
#  'MEdarkorange',
#  'MEdarkred',
#  'MEdarkturquoise',
#  'MEgreen',
#  'MEgreenyellow',
#  'MEgrey',
#  'MEgrey60',
#  'MElightcyan',
#  'MElightcyan1',
#  'MElightgreen',
#  'MElightsteelblue1',
#  'MElightyellow',
#  'MEmagenta',
#  'MEmediumpurple3',
#  'MEmidnightblue',
#  'MEorange',
#  'MEorangered4',
#  'MEpaleturquoise',
#  'MEpink',
#  'MEplum1',
#  'MEpurple',
#  'MEred',
#  'MEroyalblue',
#  'MEsaddlebrown',
#  'MEsalmon',
#  'MEsienna3',
#  'MEskyblue',
#  'MEskyblue3',
#  'MEsteelblue',
#  'MEtan',
#  'MEturquoise',
#  'MEviolet',
#  'MEwhite',
#  'MEyellow',
#  'MEyellowgreen']

# %%
col = [
 'MEgrey',    
 'MEbrown',
 'MEblue',    
 'MEblack',
 'MEturquoise',
 'MElightcyan1',    
 'MEmagenta',
 'MEcyan',
 'MEpink',
 'MEdarkturquoise',
 'MEyellow',      
 'MEgreen',
 'MEred',
 'MEmidnightblue',       
 'MEpurple',       
 'MElightcyan',       
 'MEdarkred',       
 'MEsteelblue',       
 'MEdarkgreen',       
 'MEskyblue',       
 'MEgrey60',       
 'MEtan',       
 'MEsalmon',       
 'MEdarkolivegreen',
 'MElightgreen',       
 'MEsaddlebrown',       
 'MEmediumpurple3',       
 'MEroyalblue',       
 'MEplum1',       
 'MEwhite',       
 'MEorange',
 'MEpaleturquoise',       
 'MEdarkorange',       
 'MElightyellow',       
 'MEdarkgrey',       
 'MEgreenyellow',       
 'MElightsteelblue1',       
 'MEdarkmagenta',       
 'MEskyblue3',       
 'MEorangered4',       
 'MEsienna3',       
 'MEviolet',       
 'MEyellowgreen'
]

# %%
df_reindex = df_reindex[col]

# %%
len(col)
# Out:
# 43

# %%
plt.figure(figsize = (30, 20))
sns.set(font_scale = 2)
ax = sns.heatmap(df_reindex, cmap = 'seismic', vmin = -1, vmax = 1)
plt.title('Module-sample relationships', fontsize = 30)
# plt.savefig('Module-sample relationships.png')
# plt.savefig('Module-sample relationships.jpg')
# plt.savefig('Module-sample relationships.pdf')
plt.show()
