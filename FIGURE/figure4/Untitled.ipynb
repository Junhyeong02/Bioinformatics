# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("CaCM334.MYB.ReAnnot.chromosome.ko00906.txt", sep = "\t")

# %%
df
# Out:
#                            gene      ko  \
# 0   CA.PGAv.1.6.scaffold1003.11  K09840
# 1    CA.PGAv.1.6.scaffold1026.4  K09840
# 2    CA.PGAv.1.6.scaffold396.15  K09840
# 3     CA.PGAv.1.6.scaffold396.3  K09840
# 4    CA.PGAv.1.6.scaffold485.12  K09840
# ..                          ...     ...
# 75    CA.PGAv.1.6.scaffold660.9  K09838
# 76   CA.PGAv.1.6.scaffold790.47  K02293
# 77   CA.PGAv.1.6.scaffold855.60  K14606
# 78   CA.PGAv.1.6.scaffold899.28  K17912
# 79   CA.PGAv.1.6.scaffold919.38  K14594
#
#                                                name
# 0                 9-cis-epoxycarotenoid dioxygenase
# 1                 9-cis-epoxycarotenoid dioxygenase
# 2                 9-cis-epoxycarotenoid dioxygenase
# 3                 9-cis-epoxycarotenoid dioxygenase
# 4                 9-cis-epoxycarotenoid dioxygenase
# ..                                              ...
# 75                             zeaxanthin epoxidase
# 76                       15-cis-phytoene desaturase
# ...

# %%
sortdf = df.sort_values("gene")

# %%
list((sortdf.loc[idx, 'gene'], sortdf.loc[idx, "name"]) for idx in sortdf.index)
# Out:
# [('CA.PGAv.1.6.scaffold1003.11', '9-cis-epoxycarotenoid dioxygenase'),
#  ('CA.PGAv.1.6.scaffold1026.4', '9-cis-epoxycarotenoid dioxygenase'),
#  ('CA.PGAv.1.6.scaffold1041.11', "(+)-abscisic acid 8'-hydroxylase"),
#  ('CA.PGAv.1.6.scaffold1044.2', 'violaxanthin de-epoxidase'),
#  ('CA.PGAv.1.6.scaffold1078.10', "(+)-abscisic acid 8'-hydroxylase"),
#  ('CA.PGAv.1.6.scaffold113.4', 'lycopene epsilon-cyclase'),
#  ('CA.PGAv.1.6.scaffold1209.18', 'beta-carotene isomerase'),
#  ('CA.PGAv.1.6.scaffold1209.42', 'xanthoxin dehydrogenase'),
#  ('CA.PGAv.1.6.scaffold1226.49', "(+)-abscisic acid 8'-hydroxylase"),
#  ('CA.PGAv.1.6.scaffold1237.36', 'capsanthin/capsorubin synthase'),
#  ('CA.PGAv.1.6.scaffold126.43', 'beta-carotene 3-hydroxylase'),
#  ('CA.PGAv.1.6.scaffold1288.5', 'xanthoxin dehydrogenase'),
#  ('CA.PGAv.1.6.scaffold134.163', 'zeta-carotene desaturase'),
#  ('CA.PGAv.1.6.scaffold134.165', 'zeta-carotene desaturase'),
# ...
