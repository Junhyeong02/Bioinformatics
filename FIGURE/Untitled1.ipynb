# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import seaborn as sns

# %%
plt.figure(figsize=(10, 3))
plt.subplot(1, 3, 1)

plt.plot([1,2,3,4], [1, 5, 6.7, 3], "red")
plt.xticks(visible = False)
plt.yticks([0, 5, 10], visible = False)

plt.subplot(1, 3, 2)
plt.plot([1,2,3, 4], [2, 6, 9, 5], "red")
plt.xticks(visible = False)
plt.yticks([0, 5, 10], visible = False)

plt.subplot(1, 3, 3)
plt.plot([1,2,3,4], [6, 2, 6, 8], "blue")
plt.xticks(visible = False)
plt.yticks([0, 5, 10], visible = False)




plt.suptitle("Gene expression")
plt.show()
