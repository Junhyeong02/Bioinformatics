# %%
import pandas as pd

# %%
df1 = pd.read_csv("source/Capsicum_annuum_CM334.txt", sep = "\t", index_col = "GeneID")

# %%
df2 = pd.read_csv("source/CM334.pericarp.TPM.qc.txt", sep = "\t", index_col= "GeneID")

# %%
total = pd.merge(df1, df2, right_index = True, left_index = True, how = "outer")

# %%
df1
# Out:
#                                root-1    root-2    root-3    stem-1    stem-2  \
# GeneID
# CA.PGAv.1.6.scaffold567.122  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold567.121  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold567.120  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold567.119  1.055473  0.920811  0.000000  0.994418  1.662439
# CA.PGAv.1.6.scaffold567.116  0.000000  0.000000  0.000000  0.000000  0.000000
# ...                               ...       ...       ...       ...       ...
# CA.PGAv.1.6.scaffold33767.1  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold34263.1  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold35709.1  0.381967  0.218793  0.440774  0.341742  0.394404
# CA.PGAv.1.6.scaffold36015.1  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold37009.1  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
df2
# Out:
#                              pericarp3-2  pericarp3-3  pericarp1-1  \
# GeneID
# CA.PGAv.1.6.scaffold567.120     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold567.119     0.330842     0.000000     0.350514
# CA.PGAv.1.6.scaffold567.116     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold567.118     0.000000     0.000000     0.669149
# CA.PGAv.1.6.scaffold567.113     1.456788     1.090651     0.621785
# ...                                  ...          ...          ...
# CA.PGAv.1.6.scaffold33767.1     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold35709.1     0.000000     0.520914     1.743837
# CA.PGAv.1.6.scaffold36015.1     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold36224.1     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold37009.1     0.000000     0.000000     0.000000
#
#                              pericarp1-2  pericarp1-3  pericarp2-1  \
# GeneID
# CA.PGAv.1.6.scaffold567.120     0.000000     0.000000     0.000000
# ...

# %%
new = total.fillna(0)

# %%
new
# Out:
#                                       root-1    root-2    root-3     stem-1  \
# GeneID
# CA.PGAv.1.6.scaffold1.1             0.000000  0.000000  0.000000   0.000000
# CA.PGAv.1.6.scaffold1.10            0.000000  0.000000  0.000000   0.000000
# CA.PGAv.1.6.scaffold1.11            0.450979  0.833218  1.661929   0.867620
# CA.PGAv.1.6.scaffold1.12            0.133465  0.604384  0.000000   0.128385
# CA.PGAv.1.6.scaffold1.13            0.000000  0.000000  0.000000   0.000000
# ...                                      ...       ...       ...        ...
# CaCM334_MYB.PGAv.1.6.scaffold980.1  0.000000  0.000000  0.000000   0.000000
# CaCM334_MYB.PGAv.1.6.scaffold981.1  3.482446  3.405213  4.522346   5.431122
# CaCM334_MYB.PGAv.1.6.scaffold986.1  5.280682  3.450945  3.355050  30.662008
# CaCM334_MYB.PGAv.1.6.scaffold993.1  1.543187  0.000000  2.289933  27.674715
# CaCM334_MYB.PGAv.1.6.scaffold999.1  0.000000  0.000000  0.000000   1.067465
#
# ...

# %%
new.to_csv("source/Capsicum_annuum_CM334.txt", sep = "\t")
