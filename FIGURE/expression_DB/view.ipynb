# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("source/Capsicum_annuum_CM334.txt", sep = '\t', index_col=0)

# %%
df.head()
# Out:
#                              flower-1  flower-2   leaf-2    leaf-3  leaf-4  \
# GeneID
# CA.PGAv.1.6.scaffold567.122  0.000000  0.000000  0.00000  0.000000     0.0
# CA.PGAv.1.6.scaffold567.121  0.000000  0.000000  0.00000  0.000000     0.0
# CA.PGAv.1.6.scaffold567.120  0.000000  0.000000  0.00000  0.000000     0.0
# CA.PGAv.1.6.scaffold567.119  2.316401  1.076852  1.07155  0.620351     0.0
# CA.PGAv.1.6.scaffold567.116  0.000000  0.000000  0.00000  0.000000     0.0
#
#                              placenta1-1  placenta1-2  placenta1-3  \
# GeneID
# CA.PGAv.1.6.scaffold567.122     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold567.121     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold567.120     0.000000     0.000000     0.000000
# CA.PGAv.1.6.scaffold567.119     0.716148     2.206847     1.753966
# CA.PGAv.1.6.scaffold567.116     0.000000     0.000000     0.000000
#
#                              placenta2-1  placenta2-2  ...  placentaB5-3  \
# ...

# %%
plt.figure(figsize=(30, 20))
plt.bar(df.columns, df.loc["CA.PGAv.1.6.scaffold919.38", :], color = "black", edgecolor = 'black')
plt.xticks(df.columns, rotation = 50, fontsize = 20,  horizontalalignment="center")
plt.yticks(fontsize = 30)
plt.ylabel('TPM', fontsize = 30)
plt.savefig("color_bar.png", bbox_inches = "tight")

# %% [markdown]
# plt.savefig("color_bar.png")
