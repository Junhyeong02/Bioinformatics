# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
df = pd.read_csv("Capsicum_annuum_CM334.txt", sep = "\t", index_col = "GeneID")

# %%
list(df.columns)
# Out:
# ['root-1',
#  'root-2',
#  'root-3',
#  'stem-1',
#  'stem-2',
#  'stem-3',
#  'leaf-2',
#  'leaf-3',
#  'leaf-4',
#  'flower-1',
#  'flower-2',
#  'placenta1-1',
#  'placenta1-2',
#  'placenta1-3',
#  'placenta2-1',
#  'placenta2-2',
#  'placenta2-3',
#  'placenta3-1',
#  'placenta3-2',
#  'placenta3-3',
#  'placentaMG-1',
#  'placentaMG-2',
#  'placentaMG-3',
#  'placentaB-1',
#  'placentaB-2',
#  'placentaB-3',
#  'placentaB5-1',
#  'placentaB5-2',
#  'placentaB5-3',
#  'placentaB10-1',
#  'placentaB10-2',
#  'placentaB10-3',
#  'pericarp1-1',
#  'pericarp1-2',
#  'pericarp1-3',
#  'pericarp2-1',
#  'pericarp2-2',
#  'pericarp2-3',
#  'pericarp3-1',
#  'pericarp3-2',
#  'pericarp3-3',
#  'pericarpMG-1',
#  'pericarpMG-2',
#  'pericarpMG-3',
#  'pericarpB-1',
#  'pericarpB-2',
#  'pericarpB-3',
#  'pericarpB5-3',
#  'pericarpB5-2',
#  'pericarpB5-1',
#  'pericarpB10-1',
#  'pericarpB10-2',
#  'pericarpB10-3']

# %%
df.head(5)
# Out:
#                             root-1    root-2    root-3    stem-1    stem-2  \
# GeneID
# CA.PGAv.1.6.scaffold1.1   0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold1.10  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold1.11  0.450979  0.833218  1.661929  0.867620  0.505615
# CA.PGAv.1.6.scaffold1.12  0.133465  0.604384  0.000000  0.128385  0.000000
# CA.PGAv.1.6.scaffold1.13  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                             stem-3    leaf-2    leaf-3    leaf-4  flower-1  \
# GeneID
# CA.PGAv.1.6.scaffold1.1   0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold1.10  0.000000  0.000000  0.000000  0.000000  0.000000
# CA.PGAv.1.6.scaffold1.11  0.394269  0.660545  0.000000  0.441732  0.157242
# CA.PGAv.1.6.scaffold1.12  0.148768  0.000000  0.181973  0.000000  0.000000
# CA.PGAv.1.6.scaffold1.13  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
df
# Out:
#                                       root-1    root-2    root-3     stem-1  \
# GeneID
# CA.PGAv.1.6.scaffold1.1             0.000000  0.000000  0.000000   0.000000
# CA.PGAv.1.6.scaffold1.10            0.000000  0.000000  0.000000   0.000000
# CA.PGAv.1.6.scaffold1.11            0.450979  0.833218  1.661929   0.867620
# CA.PGAv.1.6.scaffold1.12            0.133465  0.604384  0.000000   0.128385
# CA.PGAv.1.6.scaffold1.13            0.000000  0.000000  0.000000   0.000000
# ...                                      ...       ...       ...        ...
# CaCM334_MYB.PGAv.1.6.scaffold980.1  0.000000  0.000000  0.000000   0.000000
# CaCM334_MYB.PGAv.1.6.scaffold981.1  3.482446  3.405213  4.522346   5.431122
# CaCM334_MYB.PGAv.1.6.scaffold986.1  5.280682  3.450945  3.355050  30.662008
# CaCM334_MYB.PGAv.1.6.scaffold993.1  1.543187  0.000000  2.289933  27.674715
# CaCM334_MYB.PGAv.1.6.scaffold999.1  0.000000  0.000000  0.000000   1.067465
#
# ...

# %%
target_df = pd.read_csv("carotenoid.txt", sep = "\t", index_col = "v2.0")

# %%
target_df
# Out:
#                             Short name
# v2.0
# CA.PGAv.1.6.scaffold1681.17       PSY3
# NaN                               PSY2
# CA.PGAv.1.6.scaffold404.3         PSY1
# CA.PGAv.1.6.scaffold790.47         PDS
# NaN                              Z-ISO
# CA.PGAv.1.6.scaffold134.165        ZDS
# NaN                             CRTISO
# CA.PGAv.1.6.scaffold1237.36      LCYB1
# NaN                              LCYB2
# NaN                               CYCB
# CA.PGAv.1.6.scaffold126.43        BCH1
# CA.PGAv.1.6.scaffold204.19        BCH2
# CA.PGAv.1.6.scaffold794.7         ZEP1
# CA.PGAv.1.6.scaffold660.9         ZEP2
# CA.PGAv.1.6.scaffold29.20          VDE
# NaN                               NSY1
# NaN                               NSY2
# CA.PGAv.1.6.scaffold919.38         CCS
# CA.PGAv.1.6.scaffold1026.4        CCD1
# NaN                               CCD2
# NaN                               CCD3
# NaN                               CCD4
# NaN                               CCD5
# ...

# %%
pd.merge(df, target_df, how = "inner", left_index = True, right_index = True)
# Out:
#                                 root-1     root-2     root-3     stem-1  \
# CA.PGAv.1.6.scaffold1026.4    4.556015   3.723074   4.680102  93.332886
# CA.PGAv.1.6.scaffold1237.36   2.165516   5.689569   3.131496  10.015994
# CA.PGAv.1.6.scaffold126.43    2.408428   0.000000   4.038915   0.000000
# CA.PGAv.1.6.scaffold134.165  22.288383  17.917038  22.025238  28.040545
# CA.PGAv.1.6.scaffold1681.17  11.163102  18.596199  12.395483  26.716389
# CA.PGAv.1.6.scaffold204.19   20.756783  20.668684  20.408644  54.209053
# CA.PGAv.1.6.scaffold29.20     9.262280   6.281936   9.264984  58.039509
# CA.PGAv.1.6.scaffold404.3     0.000000   0.000000   0.000000   9.252074
# CA.PGAv.1.6.scaffold660.9    10.209292   5.339888   9.672703   7.651126
# CA.PGAv.1.6.scaffold68.6      0.833167   0.903401   0.205559   1.259424
# CA.PGAv.1.6.scaffold765.3     0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold790.47   13.303387  11.280026  12.785536  22.647959
# ...

# %%
my_df = pd.merge(df, target_df, how = "inner", left_index = True, right_index = True)

# %%
my_df.set_index("Short name", inplace = True)

# %%
my_df
# Out:
#                root-1     root-2     root-3     stem-1      stem-2     stem-3  \
# Short name
# CCD1         4.556015   3.723074   4.680102  93.332886  113.158943  97.603409
# LCYB1        2.165516   5.689569   3.131496  10.015994    7.962358  11.358002
# BCH1         2.408428   0.000000   4.038915   0.000000    0.000000   1.098429
# ZDS         22.288383  17.917038  22.025238  28.040545   26.066778  28.005472
# PSY3        11.163102  18.596199  12.395483  26.716389   35.600948  24.455585
# BCH2        20.756783  20.668684  20.408644  54.209053   62.366291  59.384781
# VDE          9.262280   6.281936   9.264984  58.039509   54.310638  65.228729
# PSY1         0.000000   0.000000   0.000000   9.252074    6.234322   5.386244
# ZEP2        10.209292   5.339888   9.672703   7.651126    5.119600   6.865809
# NCED4        0.833167   0.903401   0.205559   1.259424    0.000000   0.728618
# NCED7        0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# ...

# %%
# my_df.drop(["Short name"], inplace = True, axis = True)
df.columns
# Out:
# Index(['root-1', 'root-2', 'root-3', 'stem-1', 'stem-2', 'stem-3', 'leaf-2',
#        'leaf-3', 'leaf-4', 'flower-1', 'flower-2', 'placenta1-1',
#        'placenta1-2', 'placenta1-3', 'placenta2-1', 'placenta2-2',
#        'placenta2-3', 'placenta3-1', 'placenta3-2', 'placenta3-3',
#        'placentaMG-1', 'placentaMG-2', 'placentaMG-3', 'placentaB-1',
#        'placentaB-2', 'placentaB-3', 'placentaB5-1', 'placentaB5-2',
#        'placentaB5-3', 'placentaB10-1', 'placentaB10-2', 'placentaB10-3',
#        'pericarp1-1', 'pericarp1-2', 'pericarp1-3', 'pericarp2-1',
#        'pericarp2-2', 'pericarp2-3', 'pericarp3-1', 'pericarp3-2',
#        'pericarp3-3', 'pericarpMG-1', 'pericarpMG-2', 'pericarpMG-3',
#        'pericarpB-1', 'pericarpB-2', 'pericarpB-3', 'pericarpB5-3',
#        'pericarpB5-2', 'pericarpB5-1', 'pericarpB10-1', 'pericarpB10-2',
#        'pericarpB10-3'],
#       dtype='object')

# %%
my_df = my_df.div(my_df.max(axis=1), axis = 0)

# %%
my_df
# Out:
#               root-1    root-2    root-3    stem-1    stem-2    stem-3  \
# Short name
# CCD1        0.014687  0.012002  0.015087  0.300879  0.364793  0.314646
# LCYB1       0.031728  0.083360  0.045881  0.146748  0.116660  0.166411
# BCH1        0.000387  0.000000  0.000649  0.000000  0.000000  0.000177
# ZDS         0.148671  0.119512  0.146915  0.187039  0.173874  0.186805
# PSY3        0.055982  0.093259  0.062163  0.133981  0.178536  0.122643
# BCH2        0.077848  0.077518  0.076543  0.203311  0.233904  0.222722
# VDE         0.054017  0.036636  0.054032  0.338480  0.316733  0.380407
# PSY1        0.000000  0.000000  0.000000  0.002951  0.001989  0.001718
# ZEP2        0.137310  0.071819  0.130093  0.102904  0.068856  0.092341
# NCED4       0.001956  0.002121  0.000483  0.002957  0.000000  0.001711
# NCED7            NaN       NaN       NaN       NaN       NaN       NaN
# PDS         0.083987  0.071213  0.080717  0.142981  0.134530  0.121775
# ...

# %%
my_df.dropna(inplace = True)

# %%
list(my_df.index)
# Out:
# ['CCD1',
#  'LCYB1',
#  'BCH1',
#  'ZDS',
#  'PSY3',
#  'BCH2',
#  'VDE',
#  'PSY1',
#  'ZEP2',
#  'NCED4',
#  'PDS',
#  'CCD8',
#  'CCS']

# %%
[
 'PSY1',
 'PSY3', 
 'PDS',    
 'ZDS',
 'LCYB1',
 'BCH1',
 'BCH2',
 'ZEP2',    
 'VDE',  
 'CCD1',       
 'CCD8',
 'CCS',
 'NCED4'
]

# %%
plt.figure(figsize = (20, 10))
sns.set(font_scale = 2)
ax = sns.heatmap(my_df, cmap = 'rocket_r')
plt.title('Module-sample relationships', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Module-sample relationships')

# %%
my_df
# Out:
#                                        root-1    root-2    root-3    stem-1  \
# Short name
# KasI                                 0.000000  0.000000  0.000000  0.000000
# ACS1                                 0.752052  0.688289  0.978282  0.549860
# CaCM334_MYB.PGAv.1.6.scaffold1178.1  0.282612  0.380591  0.233820  0.205514
# CCD                                  0.014687  0.012002  0.015087  0.300879
# ENRb                                 0.371291  0.243467  0.356880  1.000000
# ...                                       ...       ...       ...       ...
# CaCM334_MYB.PGAv.1.6.scaffold1085.2  0.490567  0.657674  1.000000  0.000000
# CCoAOMT                              0.441835  0.354634  0.601147  0.791908
# PDH_E3                               0.518563  0.272134  0.410889  0.535731
# BCCP                                 0.415715  0.324925  0.390360  0.453565
# CaMYB31                              0.000000  0.000000  0.000000  0.000000
#
# ...
