# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import seaborn as sns

# %%
from matplotlib import rcParams, rc
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
rc('text', usetex = False)

# %%
df = pd.read_csv("../expression_DB/source/CM334.Pc.avg.tsv", sep = '\t', index_col=0)

# %%
df
# Out:
#                                Pc-0h-1    Pc-0h-2    Pc-0h-3    Pc-1h-1  \
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.116   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.118   1.509536   2.203433   1.034569   1.314173
# CA.PGAv.1.6.scaffold567.113   7.698087   9.480046   9.702389   7.551215
# CA.PGAv.1.6.scaffold567.112  16.311470  25.664545  19.853004  22.072081
# ...                                ...        ...        ...        ...
# CA.PGAv.1.6.scaffold33767.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold34263.1   1.549016   2.466012   0.000000   0.000000
# CA.PGAv.1.6.scaffold35709.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000   0.000000   0.000000   0.000000
#
#                                Pc-1h-2    Pc-1h-3    Pc-2h-1    Pc-2h-2  \
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.000000   0.357866   0.693552   0.000000
# CA.PGAv.1.6.scaffold567.116   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.118   1.162737   1.151577   1.239119   0.520381
# CA.PGAv.1.6.scaffold567.113   7.194408   7.699256   2.860622   2.617304
# CA.PGAv.1.6.scaffold567.112  13.034823  19.947273  17.470261  19.346153
# ...                                ...        ...        ...        ...
# CA.PGAv.1.6.scaffold33767.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold34263.1   0.000000   0.649914   0.000000   0.000000
# CA.PGAv.1.6.scaffold35709.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000   0.000000   0.000000   0.000000
#
#                                Pc-2h-3    Pc-4h-1  ...      Pc-12h  \
# GeneID                                             ...
# CA.PGAv.1.6.scaffold567.119   0.000000   0.000000  ...    0.000000
# CA.PGAv.1.6.scaffold567.116   0.000000   0.000000  ...    0.000000
# CA.PGAv.1.6.scaffold567.118   0.709012   0.669675  ...    0.331936
# CA.PGAv.1.6.scaffold567.113   2.060402   6.964578  ...    5.806935
# CA.PGAv.1.6.scaffold567.112  19.549545  46.948860  ...  121.218246
# ...                                ...        ...  ...         ...
# CA.PGAv.1.6.scaffold33767.1   0.000000   0.000000  ...    0.000000
# CA.PGAv.1.6.scaffold34263.1   0.000000   0.000000  ...    0.000000
# CA.PGAv.1.6.scaffold35709.1   0.000000   0.000000  ...    0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000   0.000000  ...    0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000   0.000000  ...    0.000000
#
#                                   Pc-1D     TDW-1h     TDW-2h     TDW-4h  \
# GeneID
# CA.PGAv.1.6.scaffold567.119    0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.116    0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.118    0.602004   1.160478   0.764373   0.549814
# CA.PGAv.1.6.scaffold567.113    9.121280   5.911372   6.783592   9.150812
# CA.PGAv.1.6.scaffold567.112  133.670280  15.736365  25.700145  48.362689
# ...                                 ...        ...        ...        ...
# CA.PGAv.1.6.scaffold33767.1    0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold34263.1    0.000000   0.000000   0.000000   1.466665
# CA.PGAv.1.6.scaffold35709.1    0.000000   0.000000   0.234109   0.000000
# CA.PGAv.1.6.scaffold36015.1    0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold37009.1    0.000000   0.000000   0.000000   0.000000
#
#                                 TDW-6h    TDW-12h     TDW-1D      mc-1D  \
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.000000   0.000000   0.130174   0.000000
# CA.PGAv.1.6.scaffold567.116   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.118   0.438580   0.500213   0.541170   0.318764
# CA.PGAv.1.6.scaffold567.113   7.588247   5.493839   5.027495   4.383093
# CA.PGAv.1.6.scaffold567.112  64.530379  45.877796  32.505107  44.375240
# ...                                ...        ...        ...        ...
# CA.PGAv.1.6.scaffold33767.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold34263.1   0.000000   0.000000   1.342343   0.530292
# CA.PGAv.1.6.scaffold35709.1   0.000000   0.000000   0.449540   0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000   0.000000   0.000000   0.000000
#
#                                  mc-2D
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.450950
# CA.PGAv.1.6.scaffold567.116   0.000000
# CA.PGAv.1.6.scaffold567.118   1.248067
# CA.PGAv.1.6.scaffold567.113  10.761690
# CA.PGAv.1.6.scaffold567.112  34.052257
# ...                                ...
# CA.PGAv.1.6.scaffold33767.1   0.000000
# CA.PGAv.1.6.scaffold34263.1   1.599906
# CA.PGAv.1.6.scaffold35709.1   0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000
#
# [35881 rows x 60 columns]

# %%
list(df.columns)
# Out:
# ['Pc-0h-1',
#  'Pc-0h-2',
#  'Pc-0h-3',
#  'Pc-1h-1',
#  'Pc-1h-2',
#  'Pc-1h-3',
#  'Pc-2h-1',
#  'Pc-2h-2',
#  'Pc-2h-3',
#  'Pc-4h-1',
#  'Pc-4h-2',
#  'Pc-4h-3',
#  'Pc-6h-1',
#  'Pc-6h-2',
#  'Pc-6h-3',
#  'Pc-12h-1',
#  'Pc-12h-2',
#  'Pc-12h-3',
#  'Pc-1D-1',
#  'Pc-1D-2',
#  'Pc-1D-3',
#  'TDW-1h-1',
#  'TDW-1h-2',
#  'TDW-1h-3',
#  'TDW-2h-1',
#  'TDW-2h-2',
#  'TDW-2h-3',
#  'TDW-4h-1',
#  'TDW-4h-2',
#  'TDW-4h-3',
#  'TDW-6h-1',
#  'TDW-6h-2',
#  'TDW-6h-3',
#  'TDW-12h-1',
#  'TDW-12h-2',
#  'TDW-12h-3',
#  'TDW-1D-1',
#  'TDW-1D-2',
#  'TDW-1D-3',
#  'mc-1D-1',
#  'mc-1D-2',
#  'mc-1D-3',
#  'mc-2D-1',
#  'mc-2D-2',
#  'mc-2D-3',
#  'Pc-0h',
#  'Pc-1h',
#  'Pc-2h',
#  'Pc-4h',
#  'Pc-6h',
#  'Pc-12h',
#  'Pc-1D',
#  'TDW-1h',
#  'TDW-2h',
#  'TDW-4h',
#  'TDW-6h',
#  'TDW-12h',
#  'TDW-1D',
#  'mc-1D',
#  'mc-2D']

# %%
df = df[[
 'Pc-0h',
 'Pc-1h',
 'Pc-2h',
 'Pc-4h',
 'Pc-6h',
 'Pc-12h',
 'Pc-1D',
 'TDW-1h',
 'TDW-2h',
 'TDW-4h',
 'TDW-6h',
 'TDW-12h',
 'TDW-1D']]

# %%
TDW = df[[ 
 'Pc-0h',
 'TDW-1h',
 'TDW-2h',
 'TDW-4h',
 'TDW-6h',
 'TDW-12h',
 'TDW-1D'
]]

# %%
df
# Out:
#                                  Pc-0h      Pc-1h      Pc-2h      Pc-4h  \
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.000000   0.119289   0.231184   0.000000
# CA.PGAv.1.6.scaffold567.116   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.118   1.582513   1.209496   0.822837   0.415721
# CA.PGAv.1.6.scaffold567.113   8.960174   7.481626   2.512776   7.554971
# CA.PGAv.1.6.scaffold567.112  20.609673  18.351392  18.788653  49.920588
# ...                                ...        ...        ...        ...
# CA.PGAv.1.6.scaffold33767.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold34263.1   1.338343   0.216638   0.000000   0.000000
# CA.PGAv.1.6.scaffold35709.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000   0.000000   0.000000   0.000000
#
#                                  Pc-6h      Pc-12h       Pc-1D     TDW-1h  \
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.178466    0.000000    0.000000   0.000000
# CA.PGAv.1.6.scaffold567.116   0.000000    0.000000    0.000000   0.000000
# CA.PGAv.1.6.scaffold567.118   0.741689    0.331936    0.602004   1.160478
# CA.PGAv.1.6.scaffold567.113   4.852693    5.806935    9.121280   5.911372
# CA.PGAv.1.6.scaffold567.112  69.033089  121.218246  133.670280  15.736365
# ...                                ...         ...         ...        ...
# CA.PGAv.1.6.scaffold33767.1   0.000000    0.000000    0.000000   0.000000
# CA.PGAv.1.6.scaffold34263.1   0.000000    0.000000    0.000000   0.000000
# CA.PGAv.1.6.scaffold35709.1   0.000000    0.000000    0.000000   0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000    0.000000    0.000000   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000    0.000000    0.000000   0.000000
#
#                                 TDW-2h     TDW-4h     TDW-6h    TDW-12h  \
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.116   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold567.118   0.764373   0.549814   0.438580   0.500213
# CA.PGAv.1.6.scaffold567.113   6.783592   9.150812   7.588247   5.493839
# CA.PGAv.1.6.scaffold567.112  25.700145  48.362689  64.530379  45.877796
# ...                                ...        ...        ...        ...
# CA.PGAv.1.6.scaffold33767.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold34263.1   0.000000   1.466665   0.000000   0.000000
# CA.PGAv.1.6.scaffold35709.1   0.234109   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold36015.1   0.000000   0.000000   0.000000   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000   0.000000   0.000000   0.000000
#
#                                 TDW-1D
# GeneID
# CA.PGAv.1.6.scaffold567.119   0.130174
# CA.PGAv.1.6.scaffold567.116   0.000000
# CA.PGAv.1.6.scaffold567.118   0.541170
# CA.PGAv.1.6.scaffold567.113   5.027495
# CA.PGAv.1.6.scaffold567.112  32.505107
# ...                                ...
# CA.PGAv.1.6.scaffold33767.1   0.000000
# CA.PGAv.1.6.scaffold34263.1   1.342343
# CA.PGAv.1.6.scaffold35709.1   0.449540
# CA.PGAv.1.6.scaffold36015.1   0.000000
# CA.PGAv.1.6.scaffold37009.1   0.000000
#
# [35881 rows x 13 columns]

# %%
Pc = df[[
 'Pc-0h',
 'Pc-1h',
 'Pc-2h',
 'Pc-4h',
 'Pc-6h',
 'Pc-12h',
 'Pc-1D'
]]

# %%
TDW.columns = [ 
 '0h',
 '1h',
 '2h',
 '4h',
 '6h',
 '12h',
 '1D'
]
Pc.columns = [ 
 '0h',
 '1h',
 '2h',
 '4h',
 '6h',
 '12h',
 '1D'
]

# %%
alias = "NAGLU3"
target_gene = ["CA.PGAv.1.6.scaffold219.63"]

# %%
plt.figure(figsize=(15, 10))

# color_code = [color_table_CM334[col] for col in df.columns]
width = 0.3
time = [0, 1, 2, 4, 6, 12, 24]

x = np.arange(len(time))
yticks = [0, 5, 10, 15, 20]

for val in yticks:
    plt.axhline(val, color = "grey")
    
plt.bar(x-width/2, TDW.loc[target_gene[0], :], color = "#263C65", width = width, label = "TDW")
plt.bar(x+width/2, Pc.loc[target_gene[0], :], color = "#98732F", width = width, label = "P. capsici")
plt.xticks(x, TDW.columns, fontsize = 30,  horizontalalignment="center")
# ax.set_xticks(x, TDW.columns)
plt.yticks(yticks, fontsize = 30)

plt.title(alias, fontsize = 30)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['top'].set_visible(False)
# ax1.get_yaxis().set_major_formatter(
# tick.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.gca().margins(y= 0)
plt.legend(fontsize = 20)

"""
ax2 = plt.subplot(2, 1, 2, sharex = ax1)
yticks = [0, 0.2, 0.4, 0.6, 0.8, 1]
for val in yticks:
    plt.axhline(val, color = "grey")


plt.yticks(yticks, fontsize = 45)
plt.xticks(Pc.columns, ["0h", "1h", "2h", "4h", "6h", "12h", "1D"],  fontsize = 45,  horizontalalignment="center")
plt.title("P. capsici", fontsize = 50)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['top'].set_visible(False)
# ax2.get_yaxis().set_major_formatter(
# tick.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.gca().margins(y= 0)
"""



"""
ax2 = plt.subplot(3, 1, 3, sharex = ax1)
yticks = [10, 20, 30, 40, 50]
for val in yticks:
    plt.axhline(val, color = "grey")

plt.bar(df.columns, df.loc[target_gene[2], :], color = color_code, edgecolor = 'white')
plt.yticks(yticks, fontsize = 40)
plt.xticks(df.columns, rotation = 50, fontsize = 40,  horizontalalignment="center")
plt.title(target_gene[2], fontsize = 50)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['top'].set_visible(False)
ax2.get_yaxis().set_major_formatter(
tick.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.gca().margins(y= 0)
"""

plt.savefig(f"Pc/{alias}_NAGLU3.png", bbox_inches = "tight")
plt.show()
