# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import seaborn as sns

# %%
from matplotlib import rcParams, rc
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
rc('text', usetex = False)

# %%
df = pd.read_csv("../expression_DB/source/inno/CM334.Pc.TPM.avg.txt", sep = '\t', index_col=0)

# %%
df
# Out:
#                              Mock_CM-Mock-V-0  Mock_CM-Mock-V-30m  \
# GeneID
# CA.PGAv.1.6.scaffold567.118          0.191246            0.090126
# CA.PGAv.1.6.scaffold567.113          2.851662            3.653883
# CA.PGAv.1.6.scaffold567.112         94.529663           97.064992
# CA.PGAv.1.6.scaffold567.111          6.614760           13.245957
# CA.PGAv.1.6.scaffold567.109          2.715108            2.936285
# ...                                       ...                 ...
# CA.PGAv.1.6.scaffold33211.1          0.000000            0.000000
# CA.PGAv.1.6.scaffold33767.1          0.000000            0.000000
# CA.PGAv.1.6.scaffold35709.1          0.000000            0.000000
# CA.PGAv.1.6.scaffold36015.1          0.000000            0.000000
# CA.PGAv.1.6.scaffold37009.1          0.000000            0.000000
#
#                              Mock_CM-Mock-V-4h  Mock_CM-Mock-V-1D  \
# GeneID
# CA.PGAv.1.6.scaffold567.118           0.273928           0.307265
# CA.PGAv.1.6.scaffold567.113           4.273129           2.410960
# CA.PGAv.1.6.scaffold567.112         121.004616          88.758807
# CA.PGAv.1.6.scaffold567.111          34.170693           6.146649
# CA.PGAv.1.6.scaffold567.109           4.054055           3.132181
# ...                                        ...                ...
# CA.PGAv.1.6.scaffold33211.1           0.000000           0.000000
# CA.PGAv.1.6.scaffold33767.1           0.000000           0.000000
# CA.PGAv.1.6.scaffold35709.1           0.000000           0.060255
# CA.PGAv.1.6.scaffold36015.1           0.000000           0.000000
# CA.PGAv.1.6.scaffold37009.1           0.000000           0.000000
#
#                              Mock_CM-Mock-V-2D  Mock_CM-Mock-V-3D  \
# GeneID
# CA.PGAv.1.6.scaffold567.118           0.378057           0.901618
# CA.PGAv.1.6.scaffold567.113           2.420216           2.311483
# CA.PGAv.1.6.scaffold567.112          82.470828          66.205954
# CA.PGAv.1.6.scaffold567.111           5.860899           6.070718
# CA.PGAv.1.6.scaffold567.109           3.461339           2.647451
# ...                                        ...                ...
# CA.PGAv.1.6.scaffold33211.1           0.000000           0.000000
# CA.PGAv.1.6.scaffold33767.1           0.000000           0.000000
# CA.PGAv.1.6.scaffold35709.1           0.024491           0.000000
# CA.PGAv.1.6.scaffold36015.1           0.000000           0.000000
# CA.PGAv.1.6.scaffold37009.1           0.000000           0.000000
#
#                              Mock_CM-Mock-V-up  TMV_P0_CM-P0-30m  \
# GeneID
# CA.PGAv.1.6.scaffold567.118           0.331135          0.379544
# CA.PGAv.1.6.scaffold567.113           3.776020          3.813619
# CA.PGAv.1.6.scaffold567.112          63.208799         98.140480
# CA.PGAv.1.6.scaffold567.111           3.758806         16.934029
# CA.PGAv.1.6.scaffold567.109           3.997126          3.038712
# ...                                        ...               ...
# CA.PGAv.1.6.scaffold33211.1           0.000000          0.000000
# CA.PGAv.1.6.scaffold33767.1           0.000000          0.000000
# CA.PGAv.1.6.scaffold35709.1           0.355666          0.031301
# CA.PGAv.1.6.scaffold36015.1           0.000000          0.000000
# CA.PGAv.1.6.scaffold37009.1           0.000000          0.000000
#
#                              TMV_P0_CM-P0-4h  TMV_P0_CM-P0-1D  ...  \
# GeneID                                                         ...
# CA.PGAv.1.6.scaffold567.118         0.000000         0.000000  ...
# CA.PGAv.1.6.scaffold567.113         5.071974         0.427742  ...
# CA.PGAv.1.6.scaffold567.112       142.913406        82.102247  ...
# CA.PGAv.1.6.scaffold567.111        45.030328         0.000000  ...
# CA.PGAv.1.6.scaffold567.109         2.350981         1.469596  ...
# ...                                      ...              ...  ...
# CA.PGAv.1.6.scaffold33211.1         0.000000         0.000000  ...
# CA.PGAv.1.6.scaffold33767.1         0.000000         0.000000  ...
# CA.PGAv.1.6.scaffold35709.1         0.000000         0.000000  ...
# CA.PGAv.1.6.scaffold36015.1         0.000000         0.000000  ...
# CA.PGAv.1.6.scaffold37009.1         0.000000         0.000000  ...
#
#                              Pi_12-CM-pi-1D  Pi_16-CM-pi-2D  Pi_17-CM-pi-2D  \
# GeneID
# CA.PGAv.1.6.scaffold567.118        0.611830        0.955494        2.070040
# CA.PGAv.1.6.scaffold567.113        8.967639        6.133474        7.357458
# CA.PGAv.1.6.scaffold567.112      116.885597      203.095337      252.175339
# CA.PGAv.1.6.scaffold567.111       12.930187       22.221815       30.641369
# CA.PGAv.1.6.scaffold567.109        0.000000        0.451923        0.000000
# ...                                     ...             ...             ...
# CA.PGAv.1.6.scaffold33211.1        0.000000        0.000000        0.000000
# CA.PGAv.1.6.scaffold33767.1        0.000000        0.000000        0.000000
# CA.PGAv.1.6.scaffold35709.1        1.272152        0.000000        0.000000
# CA.PGAv.1.6.scaffold36015.1        0.000000        0.000000        0.000000
# CA.PGAv.1.6.scaffold37009.1        0.000000        0.000000        0.000000
#
#                              Pi_18-CM-pi-2D  Pi_13-CM-pi-3.5D  \
# GeneID
# CA.PGAv.1.6.scaffold567.118        1.306415          1.538271
# CA.PGAv.1.6.scaffold567.113        7.680479          5.215950
# CA.PGAv.1.6.scaffold567.112      175.163300        205.213852
# CA.PGAv.1.6.scaffold567.111       22.180534         31.134165
# CA.PGAv.1.6.scaffold567.109        0.000000          0.000000
# ...                                     ...               ...
# CA.PGAv.1.6.scaffold33211.1        0.000000          0.000000
# CA.PGAv.1.6.scaffold33767.1        0.000000          0.000000
# CA.PGAv.1.6.scaffold35709.1        0.195495          0.000000
# CA.PGAv.1.6.scaffold36015.1        0.000000          0.000000
# CA.PGAv.1.6.scaffold37009.1        0.000000          0.000000
#
#                              Pi_14-CM-pi-3.5D  Pi_15-CM-pi-3.5D  \
# GeneID
# CA.PGAv.1.6.scaffold567.118          0.630562          1.488459
# CA.PGAv.1.6.scaffold567.113          7.072704          4.242060
# CA.PGAv.1.6.scaffold567.112        185.534348        190.855118
# CA.PGAv.1.6.scaffold567.111         24.160168         28.623753
# CA.PGAv.1.6.scaffold567.109          0.189910          0.000000
# ...                                       ...               ...
# CA.PGAv.1.6.scaffold33211.1          0.000000          0.000000
# CA.PGAv.1.6.scaffold33767.1          0.000000          0.000000
# CA.PGAv.1.6.scaffold35709.1          0.000000          0.000000
# CA.PGAv.1.6.scaffold36015.1          0.000000          0.000000
# CA.PGAv.1.6.scaffold37009.1          0.000000          0.000000
#
#                              Pi_19-CM-pi-5D  Pi_20-CM-pi-5D  Pi_21-CM-pi-5D
# GeneID
# CA.PGAv.1.6.scaffold567.118        1.433330        1.805571        1.429540
# CA.PGAv.1.6.scaffold567.113        5.986294        6.172638        5.179549
# CA.PGAv.1.6.scaffold567.112      147.275848      167.928238      193.670349
# CA.PGAv.1.6.scaffold567.111       26.074310       19.242067       28.389969
# CA.PGAv.1.6.scaffold567.109        0.000000        0.208532        0.000000
# ...                                     ...             ...             ...
# CA.PGAv.1.6.scaffold33211.1        0.000000        0.000000        0.000000
# CA.PGAv.1.6.scaffold33767.1        0.000000        0.000000        0.000000
# CA.PGAv.1.6.scaffold35709.1        0.146239        0.000000        0.000000
# CA.PGAv.1.6.scaffold36015.1        0.000000        0.000000        0.000000
# CA.PGAv.1.6.scaffold37009.1        0.000000        0.000000        0.000000
#
# [35881 rows x 67 columns]

# %%
list(df.columns)
# Out:
# ['Mock_CM-Mock-V-0',
#  'Mock_CM-Mock-V-30m',
#  'Mock_CM-Mock-V-4h',
#  'Mock_CM-Mock-V-1D',
#  'Mock_CM-Mock-V-2D',
#  'Mock_CM-Mock-V-3D',
#  'Mock_CM-Mock-V-up',
#  'TMV_P0_CM-P0-30m',
#  'TMV_P0_CM-P0-4h',
#  'TMV_P0_CM-P0-1D',
#  'TMV_P0_CM-P0-2D',
#  'TMV_P0_CM-P0-3D',
#  'TMV_P0_CM-P0-up',
#  'TMV_P2_CM-P2-30m',
#  'TMV_P2_CM-P2-4h',
#  'TMV_P2_CM-P2-1D',
#  'TMV_P2_CM-P2-2D',
#  'TMV_P2_CM-P2-3D',
#  'TMV_P2_CM-P2-up',
#  'Pc_CM-0h',
#  'Pc_CM-PC-1h',
#  'Pc_CM-PC-2h',
#  'Pc_CM-PC-4h',
#  'Pc_CM-PC-6h',
#  'Pc_CM-PC-12h',
#  'Pc_CM-PC-1D',
#  'Pc_CM-mc-1D',
#  'Pc_CM-mc-2D',
#  'PepMov_CM-Pep-30m',
#  'PepMov_CM-Pep-4h',
#  'PepMov_CM-Pep-1D',
#  'PepMov_CM-Pep-2D',
#  'PepMov_CM-Pep-3D',
#  'PepMov_CM-Pep-up',
#  'Pc_CM-PC-TDW-1h',
#  'Pc_CM-PC-TDW-2h',
#  'Pc_CM-PC-TDW-4h',
#  'Pc_CM-PC-TDW-6h',
#  'Pc_CM-PC-TDW-12h',
#  'Pc_CM-PC-TDW-1D',
#  'Pi_1-CM-pi-0',
#  'Pi_2-CM-pi-0',
#  'Pi_3-CM-pi-0',
#  'Pi_CM-TDW-6h',
#  'Pi_CM-TDW-12h',
#  'Pi_CM-TDW-1D',
#  'Pi_CM-TDW-2D',
#  'Pi_CM-TDW-3.5D',
#  'Pi_CM-TDW-5D',
#  'Pi_4-CM-pi-6h',
#  'Pi_5-CM-pi-6h',
#  'Pi_6-CM-pi-6h',
#  'Pi_7-CM-pi-12h',
#  'Pi_8-CM-pi-12h',
#  'Pi_9-CM-pi-12h',
#  'Pi_10-CM-pi-1D',
#  'Pi_11-CM-pi-1D',
#  'Pi_12-CM-pi-1D',
#  'Pi_16-CM-pi-2D',
#  'Pi_17-CM-pi-2D',
#  'Pi_18-CM-pi-2D',
#  'Pi_13-CM-pi-3.5D',
#  'Pi_14-CM-pi-3.5D',
#  'Pi_15-CM-pi-3.5D',
#  'Pi_19-CM-pi-5D',
#  'Pi_20-CM-pi-5D',
#  'Pi_21-CM-pi-5D']

# %%
df = df[[
 'Pc_CM-0h',
 'Pc_CM-PC-1h',
 'Pc_CM-PC-2h',
 'Pc_CM-PC-4h',
 'Pc_CM-PC-6h',
 'Pc_CM-PC-12h',
 'Pc_CM-PC-1D',
 'Pc_CM-mc-1D',
 'Pc_CM-mc-2D',
 'Pc_CM-PC-TDW-1h',
 'Pc_CM-PC-TDW-2h',
 'Pc_CM-PC-TDW-4h',
 'Pc_CM-PC-TDW-6h',
 'Pc_CM-PC-TDW-12h',
 'Pc_CM-PC-TDW-1D',
]]

# %%
df.columns = [
 '0h',
 'PC-1h',
 'PC-2h',
 'PC-4h',
 'PC-6h',
 'PC-12h',
 'PC-1D',
 'mc-1D',
 'mc-2D',
 'TDW-1h',
 'TDW-2h',
 'TDW-4h',
 'TDW-6h',
 'TDW-12h',
 'TDW-1D',
]

# %%
TDW = df[[ 
 '0h',
 'TDW-1h',
 'TDW-2h',
 'TDW-4h',
 'TDW-6h',
 'TDW-12h',
 'TDW-1D'
]]

# %%
Pc = df[[
 '0h',
 'PC-1h',
 'PC-2h',
 'PC-4h',
 'PC-6h',
 'PC-12h',
 'PC-1D',
]]

# %%
mc= df[[
     '0h',
 'mc-1D',
 'mc-2D'
]]

# %%
TDW.columns = [ 
 '0h',
 '1h',
 '2h',
 '4h',
 '6h',
 '12h',
 '1D'
]
Pc.columns = [ 
 '0h',
 '1h',
 '2h',
 '4h',
 '6h',
 '12h',
 '1D'
]

# %%
target_gene = ["CA.PGAv.1.6.scaffold919.38"]

# %%
plt.figure(figsize=(30, 10))

# color_code = [color_table_CM334[col] for col in df.columns]
width = 0.3
time = [0, 1, 2, 4, 6, 12, 24]

x = np.arange(len(time))
yticks = [0, 20, 40, 60, 80]

for val in yticks:
    plt.axhline(val, color = "grey")
    
plt.bar(x-width/2, TDW.loc[target_gene[0], :], color = "darkgreen", width = width, label = "TDW")
plt.bar(x+width/2, Pc.loc[target_gene[0], :], color = "blue", width = width, label = "P. capsici")
plt.xticks(x, TDW.columns, fontsize = 30,  horizontalalignment="center")
# ax.set_xticks(x, TDW.columns)
plt.yticks(yticks, fontsize = 45)

plt.title('CCS', fontsize = 50)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['top'].set_visible(False)
# ax1.get_yaxis().set_major_formatter(
# tick.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.gca().margins(y= 0)
# plt.legend(fontsize = 40)

"""
ax2 = plt.subplot(2, 1, 2, sharex = ax1)
yticks = [0, 0.2, 0.4, 0.6, 0.8, 1]
for val in yticks:
    plt.axhline(val, color = "grey")


plt.yticks(yticks, fontsize = 45)
plt.xticks(Pc.columns, ["0h", "1h", "2h", "4h", "6h", "12h", "1D"],  fontsize = 45,  horizontalalignment="center")
plt.title("P. capsici", fontsize = 50)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['top'].set_visible(False)
# ax2.get_yaxis().set_major_formatter(
# tick.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.gca().margins(y= 0)
"""



"""
ax2 = plt.subplot(3, 1, 3, sharex = ax1)
yticks = [10, 20, 30, 40, 50]
for val in yticks:
    plt.axhline(val, color = "grey")

plt.bar(df.columns, df.loc[target_gene[2], :], color = color_code, edgecolor = 'white')
plt.yticks(yticks, fontsize = 40)
plt.xticks(df.columns, rotation = 50, fontsize = 40,  horizontalalignment="center")
plt.title(target_gene[2], fontsize = 50)
# plt.gca().spines['right'].set_visible(False)
# plt.gca().spines['top'].set_visible(False)
ax2.get_yaxis().set_major_formatter(
tick.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.gca().margins(y= 0)
"""

plt.savefig("CCS_Pc2.png", bbox_inches = "tight")
plt.show()
